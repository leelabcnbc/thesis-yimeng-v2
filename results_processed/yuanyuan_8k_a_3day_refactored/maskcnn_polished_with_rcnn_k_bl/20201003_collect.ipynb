# %%
# this file collects all results for 8k, under 4 read out modes, up to cls=7 or 10.

# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
    explored_models_20201003_generator
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.yuanyuan_8k import get_neural_data_per_trial

cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
assert cc_max_all_neurons.shape == (79,)

# %%
f_main_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20201003', 'main_result.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 50,
        'split_seed': 'legacy',
        'dataset_prefix': 'yuanyuan_8k_a_3day',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
        'blstack_norm_type': 'instancenorm',
    },
        generator=chain(
            explored_models_20201003_generator(with_source=True),
        ),
        total_num_param=27,
        train_size_mapping={
            None: 5120,
        },
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=79,
        skip_eval_json=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600

# %%
df_main_result
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280              0.167959
#                                                                                                   2560              0.503262
#                                                                                                   5120              0.559690
#                                                                                      cm-last      1280              0.170322
#                                                                                                   2560              0.498424
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         16          1           legacy       2560              0.551408
#                                                                                                   5120              0.620538
#                                                              32          1           legacy       1280              0.404763
#                                                                                                   2560              0.565954
#                                                                                                   5120              0.628385
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280           0.079385
#                                                                                                   2560           0.236457
#                                                                                                   5120           0.258739
#                                                                                      cm-last      1280           0.080638
#                                                                                                   2560           0.233619
# ...                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       2560           0.254132
#                                                                                                   5120           0.285628
#                                                              32          1           legacy       1280           0.190003
#                                                                                                   2560           0.261334
#                                                                                                   5120           0.289346
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280          0.241002
#                                                                                                   2560          0.459860
#                                                                                                   5120          0.488410
#                                                                                      cm-last      1280          0.243113
#                                                                                                   2560          0.457843
# ...                                                                                                                  ...
# softplus True                 poisson   1          6         16          1           legacy       2560          0.484784
#                                                                                                   5120          0.517400
#                                                              32          1           legacy       1280          0.410486
#                                                                                                   2560          0.492944
#                                                                                                   5120          0.521599
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280            17461
#                                                                                                   2560            17461
#                                                                                                   5120            17461
#                                                                                      cm-last      1280            17461
#                                                                                                   2560            17461
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       2560            29837
#                                                                                                   5120            29837
#                                                              32          1           legacy       1280            67149
#                                                                                                   2560            67149
#                                                                                                   5120            67149
#
# [5616 rows x 4 columns]
