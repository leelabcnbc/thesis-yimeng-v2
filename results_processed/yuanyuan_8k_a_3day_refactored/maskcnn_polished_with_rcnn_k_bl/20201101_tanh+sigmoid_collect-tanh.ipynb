# %%
# this file collects all results for 8k, under 4 read out modes, up to cls=7 or 10.

# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
#     explored_models_20200725_generator,
    explored_models_20201101_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.yuanyuan_8k import get_neural_data_per_trial

cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
assert cc_max_all_neurons.shape == (79,)

# %%
f_main_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20201101', 'main_result_tanh.pkl')
makedirs(dirname(f_main_result), exist_ok=True)
if not exists(f_main_result):
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 50,
        'split_seed': 'legacy',
        'dataset_prefix': 'yuanyuan_8k_a_3day',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
        'act_fn_inner': 'tanh'
    },
        generator=chain(
            explored_models_20201101_generator(with_source=True, act_fn_inner_list=['tanh']),
            # more iterations cause OOM
    #             explored_models_20200801_generator(with_source=True),
    #             explored_models_20200725_generator(with_source=True),
        ),
        total_num_param=27,
        train_size_mapping={
            None: 5120,
        },
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=79,
        skip_eval_json=True,
        no_missing_data=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)

# %%
df_main_result.dropna()
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280              0.101030
#                                                                                                   2560              0.396728
#                                                                                                   5120              0.481229
#                                                                                      cm-last      1280              0.101030
#                                                                                                   2560              0.397547
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         16          1           legacy       2560              0.550410
#                                                                                                   5120              0.611079
#                                                              32          1           legacy       1280              0.487411
#                                                                                                   2560              0.579755
#                                                                                                   5120              0.628495
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280           0.045846
#                                                                                                   2560           0.188515
#                                                                                                   5120           0.224013
#                                                                                      cm-last      1280           0.045846
#                                                                                                   2560           0.188915
# ...                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       2560           0.254515
#                                                                                                   5120           0.280989
#                                                              32          1           legacy       1280           0.226524
#                                                                                                   2560           0.267421
#                                                                                                   5120           0.289227
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280          0.170492
#                                                                                                   2560          0.389237
#                                                                                                   5120          0.445645
#                                                                                      cm-last      1280          0.170492
#                                                                                                   2560          0.389456
# ...                                                                                                                  ...
# softplus True                 poisson   1          6         16          1           legacy       2560          0.483663
#                                                                                                   5120          0.513042
#                                                              32          1           legacy       1280          0.455219
#                                                                                                   2560          0.498306
#                                                                                                   5120          0.521525
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280            17461
#                                                                                                   2560            17461
#                                                                                                   5120            17461
#                                                                                      cm-last      1280            17461
#                                                                                                   2560            17461
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       2560            29837
#                                                                                                   5120            29837
#                                                              32          1           legacy       1280            67149
#                                                                                                   2560            67149
#                                                                                                   5120            67149
#
# [4464 rows x 4 columns]

# %%
# take main results and compare
f_ref_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20200725+20200801+20200801_2', 'main_result.pkl')
df_main_result_ref = pd.read_pickle(f_ref_result)

# %%
aaaa = df_main_result_ref.join(df_main_result.dropna(), how='inner', lsuffix='_ref', rsuffix='_new')

# %%
aaaa
# Out:
#                                                                                                               cc2_normed_avg_ref  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                  0.357125
#                                                                                                   2560                  0.524376
#                                                                                                   5120                  0.568387
#                                                                                      cm-last      1280                  0.357125
#                                                                                                   2560                  0.524376
# ...                                                                                                                          ...
# softplus True                 poisson   1          6         16          1           legacy       2560                  0.624076
#                                                                                                   5120                  0.658840
#                                                              32          1           legacy       1280                  0.553747
#                                                                                                   2560                  0.636960
#                                                                                                   5120                  0.674378
#
#                                                                                                               cc2_raw_avg_ref  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280               0.170239
#                                                                                                   2560               0.245452
#                                                                                                   5120               0.263209
#                                                                                      cm-last      1280               0.170239
#                                                                                                   2560               0.245452
# ...                                                                                                                       ...
# softplus True                 poisson   1          6         16          1           legacy       2560               0.287572
#                                                                                                   5120               0.303663
#                                                              32          1           legacy       1280               0.255372
#                                                                                                   2560               0.293168
#                                                                                                   5120               0.310332
#
#                                                                                                               cc_raw_avg_ref  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280              0.379368
#                                                                                                   2560              0.471792
#                                                                                                   5120              0.493379
#                                                                                      cm-last      1280              0.379368
#                                                                                                   2560              0.471792
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         16          1           legacy       2560              0.517698
#                                                                                                   5120              0.534171
#                                                              32          1           legacy       1280              0.485853
#                                                                                                   2560              0.524238
#                                                                                                   5120              0.540986
#
#                                                                                                               num_param_ref  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                17461
#                                                                                                   2560                17461
#                                                                                                   5120                17461
#                                                                                      cm-last      1280                17461
#                                                                                                   2560                17461
# ...                                                                                                                     ...
# softplus True                 poisson   1          6         16          1           legacy       2560                29837
#                                                                                                   5120                29837
#                                                              32          1           legacy       1280                67149
#                                                                                                   2560                67149
#                                                                                                   5120                67149
#
#                                                                                                               cc2_normed_avg_new  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                  0.101030
#                                                                                                   2560                  0.396728
#                                                                                                   5120                  0.481229
#                                                                                      cm-last      1280                  0.101030
#                                                                                                   2560                  0.397547
# ...                                                                                                                          ...
# softplus True                 poisson   1          6         16          1           legacy       2560                  0.550410
#                                                                                                   5120                  0.611079
#                                                              32          1           legacy       1280                  0.487411
#                                                                                                   2560                  0.579755
#                                                                                                   5120                  0.628495
#
#                                                                                                               cc2_raw_avg_new  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280               0.045846
#                                                                                                   2560               0.188515
#                                                                                                   5120               0.224013
#                                                                                      cm-last      1280               0.045846
#                                                                                                   2560               0.188915
# ...                                                                                                                       ...
# softplus True                 poisson   1          6         16          1           legacy       2560               0.254515
#                                                                                                   5120               0.280989
#                                                              32          1           legacy       1280               0.226524
#                                                                                                   2560               0.267421
#                                                                                                   5120               0.289227
#
#                                                                                                               cc_raw_avg_new  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280              0.170492
#                                                                                                   2560              0.389237
#                                                                                                   5120              0.445645
#                                                                                      cm-last      1280              0.170492
#                                                                                                   2560              0.389456
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         16          1           legacy       2560              0.483663
#                                                                                                   5120              0.513042
#                                                              32          1           legacy       1280              0.455219
#                                                                                                   2560              0.498306
#                                                                                                   5120              0.521525
#
#                                                                                                               num_param_new
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                17461
#                                                                                                   2560                17461
#                                                                                                   5120                17461
#                                                                                      cm-last      1280                17461
#                                                                                                   2560                17461
# ...                                                                                                                     ...
# softplus True                 poisson   1          6         16          1           legacy       2560                29837
#                                                                                                   5120                29837
#                                                              32          1           legacy       1280                67149
#                                                                                                   2560                67149
#                                                                                                   5120                67149
#
# [4464 rows x 8 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from thesis_v2.plots.basic import scatter

# %%
fig, ax = plt.subplots(squeeze=True);
scatter(ax, aaaa['cc2_normed_avg_ref'].values, aaaa['cc2_normed_avg_new'].values, 'ref', 'new')
plt.show()

# %%
fig, ax = plt.subplots(squeeze=True);
scatter(ax, aaaa['cc2_normed_avg_ref'].values, aaaa['cc2_normed_avg_new'].values, 'ref', 'new')
plt.show()

# %%
(aaaa['cc2_normed_avg_ref'] > aaaa['cc2_normed_avg_new']).mean()
# Out:
# 0.9471326164874552
