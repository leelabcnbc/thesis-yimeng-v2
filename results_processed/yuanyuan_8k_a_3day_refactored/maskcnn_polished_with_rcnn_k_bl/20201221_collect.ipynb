# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
    explored_models_20201221_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.yuanyuan_8k import get_neural_data_per_trial

cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
assert cc_max_all_neurons.shape == (79,)

# %%
f_main_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20201221', 'main.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 50,
        'split_seed': 'legacy',
        'dataset_prefix': 'yuanyuan_8k_a_3day',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
        'multi_path': True,
        'multi_path_separate_bn': True,
    },
        generator=chain(
            explored_models_20201221_generator(with_source=True, separate_bn_list=[True]),
        ),
        total_num_param=29,
        train_size_mapping={
            None: 5120,
        },
        no_missing_data=False,
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=79,
        skip_eval_json=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400

# %%
df_main_result
# Out:
#                                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD1          2         16          2           cm-avg       5120              0.604815
#                                                                                                      cm-last      5120              0.601255
#                                                                                                      inst-avg     5120              0.595524
#                                                                                                      inst-last    5120              0.597804
#                                                                                          3           cm-avg       5120              0.595392
# ...                                                                                                                                      ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120              0.623447
#                                                                              32          7           cm-avg       5120              0.655711
#                                                                                                      cm-last      5120              0.655711
#                                                                                                      inst-avg     5120              0.655711
#                                                                                                      inst-last    5120              0.655711
#
#                                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD1          2         16          2           cm-avg       5120           0.279256
#                                                                                                      cm-last      5120           0.277503
#                                                                                                      inst-avg     5120           0.275074
#                                                                                                      inst-last    5120           0.275800
#                                                                                          3           cm-avg       5120           0.274675
# ...                                                                                                                                   ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120           0.286317
#                                                                              32          7           cm-avg       5120           0.301155
#                                                                                                      cm-last      5120           0.301155
#                                                                                                      inst-avg     5120           0.301155
#                                                                                                      inst-last    5120           0.301155
#
#                                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD1          2         16          2           cm-avg       5120          0.509630
#                                                                                                      cm-last      5120          0.507661
#                                                                                                      inst-avg     5120          0.505995
#                                                                                                      inst-last    5120          0.506461
#                                                                                          3           cm-avg       5120          0.505300
# ...                                                                                                                                  ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120          0.518131
#                                                                              32          7           cm-avg       5120          0.532197
#                                                                                                      cm-last      5120          0.532197
#                                                                                                      inst-avg     5120          0.532197
#                                                                                                      inst-last    5120          0.532197
#
#                                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD1          2         16          2           cm-avg       5120            22909
#                                                                                                      cm-last      5120            22909
#                                                                                                      inst-avg     5120            22909
#                                                                                                      inst-last    5120            22909
#                                                                                          3           cm-avg       5120            23101
# ...                                                                                                                                 ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120            25453
#                                                                              32          7           cm-avg       5120            44557
#                                                                                                      cm-last      5120            44557
#                                                                                                      inst-avg     5120            44557
#                                                                                                      inst-last    5120            44557
#
# [3456 rows x 4 columns]

# %%
df_main_result.dropna()
# Out:
#                                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD1          2         16          2           cm-avg       5120              0.604815
#                                                                                                      cm-last      5120              0.601255
#                                                                                                      inst-avg     5120              0.595524
#                                                                                                      inst-last    5120              0.597804
#                                                                                          3           cm-avg       5120              0.595392
# ...                                                                                                                                      ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120              0.623447
#                                                                              32          7           cm-avg       5120              0.655711
#                                                                                                      cm-last      5120              0.655711
#                                                                                                      inst-avg     5120              0.655711
#                                                                                                      inst-last    5120              0.655711
#
#                                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD1          2         16          2           cm-avg       5120           0.279256
#                                                                                                      cm-last      5120           0.277503
#                                                                                                      inst-avg     5120           0.275074
#                                                                                                      inst-last    5120           0.275800
#                                                                                          3           cm-avg       5120           0.274675
# ...                                                                                                                                   ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120           0.286317
#                                                                              32          7           cm-avg       5120           0.301155
#                                                                                                      cm-last      5120           0.301155
#                                                                                                      inst-avg     5120           0.301155
#                                                                                                      inst-last    5120           0.301155
#
#                                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD1          2         16          2           cm-avg       5120          0.509630
#                                                                                                      cm-last      5120          0.507661
#                                                                                                      inst-avg     5120          0.505995
#                                                                                                      inst-last    5120          0.506461
#                                                                                          3           cm-avg       5120          0.505300
# ...                                                                                                                                  ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120          0.518131
#                                                                              32          7           cm-avg       5120          0.532197
#                                                                                                      cm-last      5120          0.532197
#                                                                                                      inst-avg     5120          0.532197
#                                                                                                      inst-last    5120          0.532197
#
#                                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD1          2         16          2           cm-avg       5120            22909
#                                                                                                      cm-last      5120            22909
#                                                                                                      inst-avg     5120            22909
#                                                                                                      inst-last    5120            22909
#                                                                                          3           cm-avg       5120            23101
# ...                                                                                                                                 ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120            25453
#                                                                              32          7           cm-avg       5120            44557
#                                                                                                      cm-last      5120            44557
#                                                                                                      inst-avg     5120            44557
#                                                                                                      inst-last    5120            44557
#
# [3456 rows x 4 columns]
