# %%
# this file collects all results for 8k, under 4 read out modes, up to cls=7 or 10.

# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
    explored_models_20200801_2_generator,
    explored_models_20200801_generator,
    explored_models_20200725_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.yuanyuan_8k import get_neural_data_per_trial

cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
assert cc_max_all_neurons.shape == (79,)

# %%
f_main_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20200725+20200801+20200801_2', 'supp_result_internal_7.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 50,
        'split_seed': 'legacy',
        'dataset_prefix': 'yuanyuan_8k_a_3day',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
    },
        generator=chain(
            explored_models_20200801_2_generator(with_source=True),
            explored_models_20200801_generator(with_source=True),
            explored_models_20200725_generator(with_source=True),
        ),
        total_num_param=26,
        train_size_mapping={
            None: 5120,
        },
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=79,
        # for metrics for cls>=2, use the the internal dynamics trained with cls=7, instead of models trained with different cls.
        internal_dynamics_cls=7,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600

# %%
df_main_result
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280              0.357125
#                                                                                                   2560              0.524376
#                                                                                                   5120              0.568387
#                                                                                      cm-last      1280              0.357125
#                                                                                                   2560              0.524376
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         16          1           legacy       2560              0.624076
#                                                                                                   5120              0.658840
#                                                              32          1           legacy       1280              0.553747
#                                                                                                   2560              0.636960
#                                                                                                   5120              0.674378
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280           0.170239
#                                                                                                   2560           0.245452
#                                                                                                   5120           0.263209
#                                                                                      cm-last      1280           0.170239
#                                                                                                   2560           0.245452
# ...                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       2560           0.287572
#                                                                                                   5120           0.303663
#                                                              32          1           legacy       1280           0.255372
#                                                                                                   2560           0.293168
#                                                                                                   5120           0.310332
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280          0.379368
#                                                                                                   2560          0.471792
#                                                                                                   5120          0.493379
#                                                                                      cm-last      1280          0.379368
#                                                                                                   2560          0.471792
# ...                                                                                                                  ...
# softplus True                 poisson   1          6         16          1           legacy       2560          0.517698
#                                                                                                   5120          0.534171
#                                                              32          1           legacy       1280          0.485853
#                                                                                                   2560          0.524238
#                                                                                                   5120          0.540986
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280          17461.0
#                                                                                                   2560          17461.0
#                                                                                                   5120          17461.0
#                                                                                      cm-last      1280          17461.0
#                                                                                                   2560          17461.0
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       2560          29837.0
#                                                                                                   5120          29837.0
#                                                              32          1           legacy       1280          67149.0
#                                                                                                   2560          67149.0
#                                                                                                   5120          67149.0
#
# [9936 rows x 4 columns]
