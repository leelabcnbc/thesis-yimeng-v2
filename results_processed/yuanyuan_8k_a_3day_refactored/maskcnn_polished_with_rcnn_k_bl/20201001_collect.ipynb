# %%
# this file collects all results for 8k, under 4 read out modes, up to cls=7 or 10.

# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
#     explored_models_20200725_generator,
    explored_models_20201001_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.yuanyuan_8k import get_neural_data_per_trial

cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
assert cc_max_all_neurons.shape == (79,)

# %%
f_main_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20201001', 'main_result.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 50,
        'split_seed': 'legacy',
        'dataset_prefix': 'yuanyuan_8k_a_3day',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
    },
        generator=chain(
            explored_models_20201001_generator(with_source=True, largest_cls=7),
            # more iterations cause OOO
#             explored_models_20200801_generator(with_source=True),
#             explored_models_20200725_generator(with_source=True),
        ),
        total_num_param=26,
        train_size_mapping={
            None: 5120,
        },
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=79,
        skip_eval_json=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900

# %%
df_main_result
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         48          1           cm-avg       1280              0.488481
#                                                                                                   2560              0.577947
#                                                                                                   5120              0.613174
#                                                                                      cm-last      1280              0.488481
#                                                                                                   2560              0.577947
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         48          1           legacy       2560              0.629205
#                                                                                                   5120              0.681167
#                                                              64          1           legacy       1280              0.561157
#                                                                                                   2560              0.632569
#                                                                                                   5120              0.682993
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         48          1           cm-avg       1280           0.229924
#                                                                                                   2560           0.268561
#                                                                                                   5120           0.282168
#                                                                                      cm-last      1280           0.229924
#                                                                                                   2560           0.268561
# ...                                                                                                                   ...
# softplus True                 poisson   1          6         48          1           legacy       2560           0.289585
#                                                                                                   5120           0.313140
#                                                              64          1           legacy       1280           0.259474
#                                                                                                   2560           0.291328
#                                                                                                   5120           0.313777
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         48          1           cm-avg       1280          0.453627
#                                                                                                   2560          0.497928
#                                                                                                   5120          0.514229
#                                                                                      cm-last      1280          0.453627
#                                                                                                   2560          0.497928
# ...                                                                                                                  ...
# softplus True                 poisson   1          6         48          1           legacy       2560          0.520500
#                                                                                                   5120          0.543658
#                                                              64          1           legacy       1280          0.489701
#                                                                                                   2560          0.522591
#                                                                                                   5120          0.544308
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         48          1           cm-avg       1280            44221
#                                                                                                   2560            44221
#                                                                                                   5120            44221
#                                                                                      cm-last      1280            44221
#                                                                                                   2560            44221
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         48          1           legacy       2560           127501
#                                                                                                   5120           127501
#                                                              64          1           legacy       1280           210893
#                                                                                                   2560           210893
#                                                                                                   5120           210893
#
# [2976 rows x 4 columns]
