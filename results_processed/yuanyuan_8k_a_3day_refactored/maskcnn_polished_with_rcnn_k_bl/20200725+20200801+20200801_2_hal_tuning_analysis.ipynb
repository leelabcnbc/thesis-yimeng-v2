# %%
# this file collects all results for 8k, under 4 read out modes, up to cls=7 or 10.

# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
    explored_models_20200801_2_generator,
    explored_models_20200801_generator,
    explored_models_20200725_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_hal_analysis

# %%
import pandas as pd

# %%
f_main_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20200725+20200801+20200801_2', 'hal_tuning_complete.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_hal_analysis(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 50,
        'split_seed': 'legacy',
        'dataset_prefix': 'yuanyuan_8k_a_3day',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
    },
        generator=chain(
            explored_models_20200801_2_generator(with_source=True),
            explored_models_20200801_generator(with_source=True),
            explored_models_20200725_generator(with_source=True),
        ),
        total_num_param=26,
        train_size_mapping={
            None: 5120,
        },
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# /opt/conda/envs/leelab/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 834 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 1104 tasks      | elapsed: 26.4min
# [Parallel(n_jobs=-1)]: Done 1410 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done 1752 tasks      | elapsed: 33.7min
# [Parallel(n_jobs=-1)]: Done 2130 tasks      | elapsed: 38.0min
# [Parallel(n_jobs=-1)]: Done 2544 tasks      | elapsed: 42.6min
# [Parallel(n_jobs=-1)]: Done 2994 tasks      | elapsed: 47.6min
# [Parallel(n_jobs=-1)]: Done 3480 tasks      | elapsed: 57.5min
# [Parallel(n_jobs=-1)]: Done 4002 tasks      | elapsed: 70.9min
# [Parallel(n_jobs=-1)]: Done 4560 tasks      | elapsed: 88.8min
# [Parallel(n_jobs=-1)]: Done 5154 tasks      | elapsed: 108.7min
# [Parallel(n_jobs=-1)]: Done 5784 tasks      | elapsed: 129.4min
# [Parallel(n_jobs=-1)]: Done 6450 tasks      | elapsed: 152.1min
# [Parallel(n_jobs=-1)]: Done 7152 tasks      | elapsed: 173.2min
# [Parallel(n_jobs=-1)]: Done 7890 tasks      | elapsed: 189.6min
# [Parallel(n_jobs=-1)]: Done 8664 tasks      | elapsed: 206.8min
# [Parallel(n_jobs=-1)]: Done 9474 tasks      | elapsed: 212.4min
# [Parallel(n_jobs=-1)]: Done 9648 out of 9648 | elapsed: 213.6min finished

# %%
df_main_result
# Out:
#                                                                                                              hal_tuning_analysis  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                      None
#                                                                                                   2560                      None
#                                                                                                   5120                      None
#                                                                                      cm-last      1280                      None
#                                                                                                   2560                      None
# ...                                                                                                                          ...
# softplus True                 poisson   1          6         16          1           legacy       2560                      None
#                                                                                                   5120                      None
#                                                              32          1           legacy       1280                      None
#                                                                                                   2560                      None
#                                                                                                   5120                      None
#
#                                                                                                              hal_tuning_analysis_half_improved  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                                    None
#                                                                                                   2560                                    None
#                                                                                                   5120                                    None
#                                                                                      cm-last      1280                                    None
#                                                                                                   2560                                    None
# ...                                                                                                                                        ...
# softplus True                 poisson   1          6         16          1           legacy       2560                                    None
#                                                                                                   5120                                    None
#                                                              32          1           legacy       1280                                    None
#                                                                                                   2560                                    None
#                                                                                                   5120                                    None
#
#                                                                                                              hal_tuning_analysis_half_improved_baseline  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                                             None
#                                                                                                   2560                                             None
#                                                                                                   5120                                             None
#                                                                                      cm-last      1280                                             None
#                                                                                                   2560                                             None
# ...                                                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       2560                                             None
#                                                                                                   5120                                             None
#                                                              32          1           legacy       1280                                             None
#                                                                                                   2560                                             None
#                                                                                                   5120                                             None
#
#                                                                                                              hal_tuning_analysis_improved  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                               None
#                                                                                                   2560                               None
#                                                                                                   5120                               None
#                                                                                      cm-last      1280                               None
#                                                                                                   2560                               None
# ...                                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       2560                               None
#                                                                                                   5120                               None
#                                                              32          1           legacy       1280                               None
#                                                                                                   2560                               None
#                                                                                                   5120                               None
#
#                                                                                                              hal_tuning_analysis_improved_baseline  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                                        None
#                                                                                                   2560                                        None
#                                                                                                   5120                                        None
#                                                                                      cm-last      1280                                        None
#                                                                                                   2560                                        None
# ...                                                                                                                                            ...
# softplus True                 poisson   1          6         16          1           legacy       2560                                        None
#                                                                                                   5120                                        None
#                                                              32          1           legacy       1280                                        None
#                                                                                                   2560                                        None
#                                                                                                   5120                                        None
#
#                                                                                                              hal_tuning_analysis_inverted  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                               None
#                                                                                                   2560                               None
#                                                                                                   5120                               None
#                                                                                      cm-last      1280                               None
#                                                                                                   2560                               None
# ...                                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       2560                               None
#                                                                                                   5120                               None
#                                                              32          1           legacy       1280                               None
#                                                                                                   2560                               None
#                                                                                                   5120                               None
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280            17461
#                                                                                                   2560            17461
#                                                                                                   5120            17461
#                                                                                      cm-last      1280            17461
#                                                                                                   2560            17461
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       2560            29837
#                                                                                                   5120            29837
#                                                              32          1           legacy       1280            67149
#                                                                                                   2560            67149
#                                                                                                   5120            67149
#
# [9648 rows x 7 columns]
