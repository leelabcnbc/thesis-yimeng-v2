# %%
# this file collects all results for 8k, under 4 read out modes, up to cls=7 or 10.

# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
#     explored_models_20200725_generator,
    explored_models_20201012_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.yuanyuan_8k import get_neural_data_per_trial

cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
assert cc_max_all_neurons.shape == (79,)

# %%
f_main_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20201012', 'main_result.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 50,
        'split_seed': 'legacy',
        'dataset_prefix': 'yuanyuan_8k_a_3day',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
    },
        generator=chain(
            explored_models_20201012_generator(with_source=True),
            # more iterations cause OOM
#             explored_models_20200801_generator(with_source=True),
#             explored_models_20200725_generator(with_source=True),
        ),
        total_num_param=26,
        train_size_mapping={
            None: 5120,
        },
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=79,
        skip_eval_json=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600

# %%
df_main_result
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         48          1           inst-avg     1280              0.497211
#                                                                                                   2560              0.581428
#                                                                                                   5120              0.611132
#                                                                                      inst-last    1280              0.497211
#                                                                                                   2560              0.581428
# ...                                                                                                                      ...
# softplus True                 poisson   1          3         64          7           inst-avg     2560              0.662721
#                                                                                                   5120              0.701539
#                                                                                      inst-last    1280              0.526869
#                                                                                                   2560              0.621077
#                                                                                                   5120              0.677992
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         48          1           inst-avg     1280           0.234784
#                                                                                                   2560           0.269984
#                                                                                                   5120           0.281301
#                                                                                      inst-last    1280           0.234784
#                                                                                                   2560           0.269984
# ...                                                                                                                   ...
# softplus True                 poisson   1          3         64          7           inst-avg     2560           0.305368
#                                                                                                   5120           0.322235
#                                                                                      inst-last    1280           0.243357
#                                                                                                   2560           0.285823
#                                                                                                   5120           0.311802
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         48          1           inst-avg     1280          0.458994
#                                                                                                   2560          0.499504
#                                                                                                   5120          0.513519
#                                                                                      inst-last    1280          0.458994
#                                                                                                   2560          0.499504
# ...                                                                                                                  ...
# softplus True                 poisson   1          3         64          7           inst-avg     2560          0.535887
#                                                                                                   5120          0.552229
#                                                                                      inst-last    1280          0.472035
#                                                                                                   2560          0.515495
#                                                                                                   5120          0.541974
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         48          1           inst-avg     1280            44221
#                                                                                                   2560            44221
#                                                                                                   5120            44221
#                                                                                      inst-last    1280            44221
#                                                                                                   2560            44221
# ...                                                                                                                 ...
# softplus True                 poisson   1          3         64          7           inst-avg     2560           175181
#                                                                                                   5120           175181
#                                                                                      inst-last    1280           175181
#                                                                                                   2560           175181
#                                                                                                   5120           175181
#
# [2688 rows x 4 columns]
