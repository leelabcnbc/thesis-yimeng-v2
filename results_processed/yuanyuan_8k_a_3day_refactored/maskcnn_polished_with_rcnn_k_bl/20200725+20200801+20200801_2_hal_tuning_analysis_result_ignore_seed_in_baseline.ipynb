# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice
# %matplotlib inline

from thesis_v2 import dir_dict
from thesis_v2.plots.hal_tuning_analysis import show_scatter_plots

# %%
import pandas as pd

# %%
f_main_result = join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20200725+20200801+20200801_2', 'hal_tuning_complete_ignore_seed_in_baseline.pkl')
df_main_result = pd.read_pickle(f_main_result)
# remove cls>7 results
df_main_result = df_main_result[df_main_result.index.get_level_values('rcnn_bl_cls')<=7].sort_index()

# %%
df_main_result
# Out:
#                                                                                                              hal_tuning_analysis  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                      None
#                                                                                                   2560                      None
#                                                                                                   5120                      None
#                                                                                      cm-last      1280                      None
#                                                                                                   2560                      None
# ...                                                                                                                          ...
# softplus True                 poisson   1          6         16          1           legacy       2560                      None
#                                                                                                   5120                      None
#                                                              32          1           legacy       1280                      None
#                                                                                                   2560                      None
#                                                                                                   5120                      None
#
#                                                                                                              hal_tuning_analysis_half_improved  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                                    None
#                                                                                                   2560                                    None
#                                                                                                   5120                                    None
#                                                                                      cm-last      1280                                    None
#                                                                                                   2560                                    None
# ...                                                                                                                                        ...
# softplus True                 poisson   1          6         16          1           legacy       2560                                    None
#                                                                                                   5120                                    None
#                                                              32          1           legacy       1280                                    None
#                                                                                                   2560                                    None
#                                                                                                   5120                                    None
#
#                                                                                                              hal_tuning_analysis_half_improved_baseline  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                                             None
#                                                                                                   2560                                             None
#                                                                                                   5120                                             None
#                                                                                      cm-last      1280                                             None
#                                                                                                   2560                                             None
# ...                                                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       2560                                             None
#                                                                                                   5120                                             None
#                                                              32          1           legacy       1280                                             None
#                                                                                                   2560                                             None
#                                                                                                   5120                                             None
#
#                                                                                                              hal_tuning_analysis_improved  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                               None
#                                                                                                   2560                               None
#                                                                                                   5120                               None
#                                                                                      cm-last      1280                               None
#                                                                                                   2560                               None
# ...                                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       2560                               None
#                                                                                                   5120                               None
#                                                              32          1           legacy       1280                               None
#                                                                                                   2560                               None
#                                                                                                   5120                               None
#
#                                                                                                              hal_tuning_analysis_improved_baseline  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                                        None
#                                                                                                   2560                                        None
#                                                                                                   5120                                        None
#                                                                                      cm-last      1280                                        None
#                                                                                                   2560                                        None
# ...                                                                                                                                            ...
# softplus True                 poisson   1          6         16          1           legacy       2560                                        None
#                                                                                                   5120                                        None
#                                                              32          1           legacy       1280                                        None
#                                                                                                   2560                                        None
#                                                                                                   5120                                        None
#
#                                                                                                              hal_tuning_analysis_inverted  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280                               None
#                                                                                                   2560                               None
#                                                                                                   5120                               None
#                                                                                      cm-last      1280                               None
#                                                                                                   2560                               None
# ...                                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       2560                               None
#                                                                                                   5120                               None
#                                                              32          1           legacy       1280                               None
#                                                                                                   2560                               None
#                                                                                                   5120                               None
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280            17461
#                                                                                                   2560            17461
#                                                                                                   5120            17461
#                                                                                      cm-last      1280            17461
#                                                                                                   2560            17461
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       2560            29837
#                                                                                                   5120            29837
#                                                              32          1           legacy       1280            67149
#                                                                                                   2560            67149
#                                                                                                   5120            67149
#
# [8784 rows x 7 columns]

# %%
show_scatter_plots(df_main_result)
# Out:
# (6912, 2)
# overall
# baseline mean 0.0086, sem 0.0012
# learned mean 0.0419, sem 0.0009
# % of pairs, learned > mean 63.01
# cm-avg
# baseline mean 0.0081, sem 0.0023
# learned mean 0.0313, sem 0.0020
# % of pairs, learned > mean 60.47
# cm-last
# baseline mean 0.0071, sem 0.0023
# learned mean 0.0565, sem 0.0017
# % of pairs, learned > mean 68.63
# inst-avg
# baseline mean 0.0100, sem 0.0023
# learned mean 0.0497, sem 0.0018
# % of pairs, learned > mean 65.05
# inst-last
# baseline mean 0.0093, sem 0.0024
# learned mean 0.0302, sem 0.0018
# % of pairs, learned > mean 57.87
# (6912, 2)
# overall
# baseline mean 0.0088, sem 0.0012
# learned mean 0.0400, sem 0.0009
# % of pairs, learned > mean 62.46
# cm-avg
# baseline mean 0.0074, sem 0.0023
# learned mean 0.0305, sem 0.0019
# % of pairs, learned > mean 61.28
# cm-last
# baseline mean 0.0089, sem 0.0023
# learned mean 0.0536, sem 0.0017
# % of pairs, learned > mean 67.13
# inst-avg
# baseline mean 0.0101, sem 0.0023
# learned mean 0.0476, sem 0.0018
# % of pairs, learned > mean 64.24
# inst-last
# baseline mean 0.0090, sem 0.0023
# learned mean 0.0282, sem 0.0018
# % of pairs, learned > mean 57.18
