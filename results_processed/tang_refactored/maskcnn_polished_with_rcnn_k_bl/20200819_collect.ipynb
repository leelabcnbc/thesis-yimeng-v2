# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
    explored_models_20200819_tang_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.gaya import get_neural_data
raw_data = get_neural_data(dataset='tang', return_raw=True)
# cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
# assert cc_max_all_neurons.shape == (79,)

# %%
len(raw_data)
# Out:
# 2250

# %%
import numpy as np
# use first eight trials to get ccmax.
# each image at least has 8 trials. this will be a bit inaccurate but should be ok. with similar results as 
# a more proper way to get ccmax.
a = np.asarray([x[:8] for x in raw_data]).T

# %%
print(a.shape)  # (num_neuron x num_trial x num_time)
cc_max_all_neurons=cc_max(a)
assert cc_max_all_neurons.shape==(34,)
# Out:
# (34, 8, 2250)

# %%
f_main_result = join(dir_dict['analyses'], 'tang_refactored', '20200819', 'main_result.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 63,
        'split_seed': 'legacy',
        'dataset_prefix': 'tang',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
    },
        generator=chain(
            explored_models_20200819_tang_generator(with_source=True),
        ),
        total_num_param=26,
        train_size_mapping=dict(),
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=34,
        skip_eval_json=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700

# %%
df_main_result
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350               0.259081
#                                                                                                   700               0.423521
#                                                                                                   1400              0.513970
#                                                                                      cm-last      350               0.260391
#                                                                                                   700               0.423521
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         16          1           legacy       700               0.524279
#                                                                                                   1400              0.586472
#                                                              32          1           legacy       350               0.436058
#                                                                                                   700               0.541762
#                                                                                                   1400              0.604707
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350            0.230539
#                                                                                                   700            0.374998
#                                                                                                   1400           0.452182
#                                                                                      cm-last      350            0.231683
#                                                                                                   700            0.374998
# ...                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       700            0.460725
#                                                                                                   1400           0.514649
#                                                              32          1           legacy       350            0.383985
#                                                                                                   700            0.475280
#                                                                                                   1400           0.529852
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350           0.439965
#                                                                                                   700           0.571779
#                                                                                                   1400          0.652022
#                                                                                      cm-last      350           0.441123
#                                                                                                   700           0.571779
# ...                                                                                                                  ...
# softplus True                 poisson   1          6         16          1           legacy       700           0.660011
#                                                                                                   1400          0.702086
#                                                              32          1           legacy       350           0.596201
#                                                                                                   700           0.675253
#                                                                                                   1400          0.715438
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350             13846
#                                                                                                   700             13846
#                                                                                                   1400            13846
#                                                                                      cm-last      350             13846
#                                                                                                   700             13846
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       700             25862
#                                                                                                   1400            25862
#                                                              32          1           legacy       350             62454
#                                                                                                   700             62454
#                                                                                                   1400            62454
#
# [4752 rows x 4 columns]

# %%
# cc max is very high.
cc_max_all_neurons
# Out:
# array([0.95095694, 0.9660031 , 0.9724277 , 0.9708895 , 0.9581036 ,
#        0.89705384, 0.93397653, 0.9264926 , 0.9247743 , 0.9671467 ,
#        0.9304361 , 0.97559494, 0.92820185, 0.9599929 , 0.95907646,
#        0.96021706, 0.7633961 , 0.9247523 , 0.9311054 , 0.9290246 ,
#        0.9438151 , 0.93616587, 0.9794097 , 0.867756  , 0.9529409 ,
#        0.91466427, 0.82111335, 0.94250643, 0.8201825 , 0.9762719 ,
#        0.93890166, 0.926197  , 0.97848314, 0.9247499 ], dtype=float32)
