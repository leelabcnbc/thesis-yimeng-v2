# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
    explored_models_20201018_tang_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.gaya import get_neural_data
raw_data = get_neural_data(dataset='tang', return_raw=True, start_offset=0, end_offset=500)
# cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
# assert cc_max_all_neurons.shape == (79,)

# %%
len(raw_data)
# Out:
# 2250

# %%
import numpy as np
# use first eight trials to get ccmax.
# each image at least has 8 trials. this will be a bit inaccurate but should be ok. with similar results as 
# a more proper way to get ccmax.
a = np.asarray([x[:8] for x in raw_data]).T

# %%
print(a.shape)  # (num_neuron x num_trial x num_time)
cc_max_all_neurons=cc_max(a)
assert cc_max_all_neurons.shape==(34,)
# Out:
# (34, 8, 2250)

# %%
f_main_result = join(dir_dict['analyses'], 'tang_refactored', '20201018', 'main_result_0,500.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 37,
        'split_seed': 'legacy',
        'dataset_prefix': 'tang',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
        'additional_key': '0,500'
    },
        generator=chain(
            explored_models_20201018_tang_generator(with_source=True, additional_keys=('0,500',)),
        ),
        total_num_param=27,
        train_size_mapping=dict(),
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=34,
        skip_eval_json=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000

# %%
df_main_result
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           inst-avg     350               0.260392
#                                                                                                   700               0.345669
#                                                                                                   1400              0.396416
#                                                                                      inst-last    350               0.260392
#                                                                                                   700               0.345669
# ...                                                                                                                      ...
# softplus True                 poisson   1          3         32          7           inst-avg     700               0.454410
#                                                                                                   1400              0.505486
#                                                                                      inst-last    350               0.331365
#                                                                                                   700               0.394587
#                                                                                                   1400              0.462735
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           inst-avg     350            0.242842
#                                                                                                   700            0.322136
#                                                                                                   1400           0.368840
#                                                                                      inst-last    350            0.242842
#                                                                                                   700            0.322136
# ...                                                                                                                   ...
# softplus True                 poisson   1          3         32          7           inst-avg     700            0.421986
#                                                                                                   1400           0.468526
#                                                                                      inst-last    350            0.307956
#                                                                                                   700            0.366663
#                                                                                                   1400           0.428704
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           inst-avg     350           0.449782
#                                                                                                   700           0.527187
#                                                                                                   1400          0.578230
#                                                                                      inst-last    350           0.449782
#                                                                                                   700           0.527187
# ...                                                                                                                  ...
# softplus True                 poisson   1          3         32          7           inst-avg     700           0.623391
#                                                                                                   1400          0.664512
#                                                                                      inst-last    350           0.524116
#                                                                                                   700           0.572889
#                                                                                                   1400          0.634703
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           inst-avg     350              4972
#                                                                                                   700              4972
#                                                                                                   1400             4972
#                                                                                      inst-last    350              4972
#                                                                                                   700              4972
# ...                                                                                                                 ...
# softplus True                 poisson   1          3         32          7           inst-avg     700             44940
#                                                                                                   1400            44940
#                                                                                      inst-last    350             44940
#                                                                                                   700             44940
#                                                                                                   1400            44940
#
# [4032 rows x 4 columns]

# %%
cc_max_all_neurons
# Out:
# array([0.96998745, 0.9758504 , 0.9775312 , 0.9797223 , 0.9767138 ,
#        0.9504543 , 0.9613976 , 0.9583695 , 0.94375265, 0.9809341 ,
#        0.9613362 , 0.98089325, 0.9625241 , 0.97526   , 0.97735155,
#        0.97869885, 0.7933633 , 0.94768   , 0.97189534, 0.9721385 ,
#        0.9697133 , 0.95554984, 0.98594475, 0.9309055 , 0.9727706 ,
#        0.94989777, 0.8878589 , 0.9800052 , 0.90470195, 0.9841685 ,
#        0.97346646, 0.96128666, 0.98449636, 0.96764106], dtype=float32)
