# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
    explored_models_20200930_tang_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.gaya import get_neural_data
raw_data = get_neural_data(dataset='tang', return_raw=True)
# cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
# assert cc_max_all_neurons.shape == (79,)

# %%
len(raw_data)
# Out:
# 2250

# %%
import numpy as np
# use first eight trials to get ccmax.
# each image at least has 8 trials. this will be a bit inaccurate but should be ok. with similar results as 
# a more proper way to get ccmax.
a = np.asarray([x[:8] for x in raw_data]).T

# %%
print(a.shape)  # (num_neuron x num_trial x num_time)
cc_max_all_neurons=cc_max(a)
assert cc_max_all_neurons.shape==(34,)
# Out:
# (34, 8, 2250)

# %%
f_main_result = join(dir_dict['analyses'], 'tang_refactored', '20200930', 'main_result.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 37,
        'split_seed': 'legacy',
        'dataset_prefix': 'tang',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
    },
        generator=chain(
            explored_models_20200930_tang_generator(with_source=True),
        ),
        total_num_param=26,
        train_size_mapping=dict(),
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=34,
        skip_eval_json=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)

# %%
df_main_result
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350               0.347874
#                                                                                                   700               0.417374
#                                                                                                   1400              0.507518
#                                                                                      cm-last      350               0.340426
#                                                                                                   700               0.437379
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         16          1           legacy       700               0.510149
#                                                                                                   1400              0.561252
#                                                              32          1           legacy       350               0.421001
#                                                                                                   700               0.500953
#                                                                                                   1400              0.565751
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350            0.309365
#                                                                                                   700            0.369558
#                                                                                                   1400           0.448455
#                                                                                      cm-last      350            0.302438
#                                                                                                   700            0.387133
# ...                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       700            0.450092
#                                                                                                   1400           0.494668
#                                                              32          1           legacy       350            0.372713
#                                                                                                   700            0.442037
#                                                                                                   1400           0.497538
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350           0.512489
#                                                                                                   700           0.573166
#                                                                                                   1400          0.643554
#                                                                                      cm-last      350           0.509035
#                                                                                                   700           0.587934
# ...                                                                                                                  ...
# softplus True                 poisson   1          6         16          1           legacy       700           0.641424
#                                                                                                   1400          0.678182
#                                                              32          1           legacy       350           0.568769
#                                                                                                   700           0.632598
#                                                                                                   1400          0.682976
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350              4972
#                                                                                                   700              4972
#                                                                                                   1400             4972
#                                                                                      cm-last      350              4972
#                                                                                                   700              4972
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       700             16988
#                                                                                                   1400            16988
#                                                              32          1           legacy       350             53580
#                                                                                                   700             53580
#                                                                                                   1400            53580
#
# [4752 rows x 4 columns]
