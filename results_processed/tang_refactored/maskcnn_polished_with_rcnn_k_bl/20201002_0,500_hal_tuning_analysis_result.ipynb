# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice

# %matplotlib inline

from thesis_v2 import dir_dict

from thesis_v2.plots.hal_tuning_analysis import show_scatter_plots

# %%
import pandas as pd

# %%
f_main_result = join(dir_dict['analyses'], 'tang_refactored', '20201002_0,500', 'hal_tuning_complete_ignore_seed_in_baseline.pkl')
df_main_result = pd.read_pickle(f_main_result)
# remove cls>7 results
df_main_result = df_main_result[df_main_result.index.get_level_values('rcnn_bl_cls')<=7].sort_index()

# %%
df_main_result
# Out:
#                                                                                                              hal_tuning_analysis  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350                       None
#                                                                                                   700                       None
#                                                                                                   1400                      None
#                                                                                      cm-last      350                       None
#                                                                                                   700                       None
# ...                                                                                                                          ...
# softplus True                 poisson   1          6         16          1           legacy       700                       None
#                                                                                                   1400                      None
#                                                              32          1           legacy       350                       None
#                                                                                                   700                       None
#                                                                                                   1400                      None
#
#                                                                                                              hal_tuning_analysis_half_improved  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350                                     None
#                                                                                                   700                                     None
#                                                                                                   1400                                    None
#                                                                                      cm-last      350                                     None
#                                                                                                   700                                     None
# ...                                                                                                                                        ...
# softplus True                 poisson   1          6         16          1           legacy       700                                     None
#                                                                                                   1400                                    None
#                                                              32          1           legacy       350                                     None
#                                                                                                   700                                     None
#                                                                                                   1400                                    None
#
#                                                                                                              hal_tuning_analysis_half_improved_baseline  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350                                              None
#                                                                                                   700                                              None
#                                                                                                   1400                                             None
#                                                                                      cm-last      350                                              None
#                                                                                                   700                                              None
# ...                                                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       700                                              None
#                                                                                                   1400                                             None
#                                                              32          1           legacy       350                                              None
#                                                                                                   700                                              None
#                                                                                                   1400                                             None
#
#                                                                                                              hal_tuning_analysis_improved  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350                                None
#                                                                                                   700                                None
#                                                                                                   1400                               None
#                                                                                      cm-last      350                                None
#                                                                                                   700                                None
# ...                                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       700                                None
#                                                                                                   1400                               None
#                                                              32          1           legacy       350                                None
#                                                                                                   700                                None
#                                                                                                   1400                               None
#
#                                                                                                              hal_tuning_analysis_improved_baseline  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350                                         None
#                                                                                                   700                                         None
#                                                                                                   1400                                        None
#                                                                                      cm-last      350                                         None
#                                                                                                   700                                         None
# ...                                                                                                                                            ...
# softplus True                 poisson   1          6         16          1           legacy       700                                         None
#                                                                                                   1400                                        None
#                                                              32          1           legacy       350                                         None
#                                                                                                   700                                         None
#                                                                                                   1400                                        None
#
#                                                                                                              hal_tuning_analysis_inverted  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350                                None
#                                                                                                   700                                None
#                                                                                                   1400                               None
#                                                                                      cm-last      350                                None
#                                                                                                   700                                None
# ...                                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       700                                None
#                                                                                                   1400                               None
#                                                              32          1           legacy       350                                None
#                                                                                                   700                                None
#                                                                                                   1400                               None
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350              4972
#                                                                                                   700              4972
#                                                                                                   1400             4972
#                                                                                      cm-last      350              4972
#                                                                                                   700              4972
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       700             16988
#                                                                                                   1400            16988
#                                                              32          1           legacy       350             53580
#                                                                                                   700             53580
#                                                                                                   1400            53580
#
# [4752 rows x 7 columns]

# %%
show_scatter_plots(df_main_result)
# Out:
# (3456, 2)
# overall
# baseline mean 0.0045, sem 0.0016
# learned mean 0.0315, sem 0.0014
# % of pairs, learned > mean 58.25%
# cm-avg
# baseline mean 0.0055, sem 0.0022
# learned mean 0.0294, sem 0.0020
# % of pairs, learned > mean 57.23%
# cm-last
# baseline mean 0.0034, sem 0.0023
# learned mean 0.0335, sem 0.0020
# % of pairs, learned > mean 59.26%
# (3456, 2)
# overall
# baseline mean 0.0046, sem 0.0016
# learned mean 0.0338, sem 0.0014
# % of pairs, learned > mean 59.66%
# cm-avg
# baseline mean 0.0064, sem 0.0022
# learned mean 0.0298, sem 0.0020
# % of pairs, learned > mean 57.87%
# cm-last
# baseline mean 0.0028, sem 0.0023
# learned mean 0.0378, sem 0.0019
# % of pairs, learned > mean 61.46%
