# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain

from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import (
    explored_models_20201026_tang_generator,
)
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result

# %%
import pandas as pd

# %%
# get cc_max
from strflab.stats import cc_max
from thesis_v2.data.prepared.gaya import get_neural_data
raw_data = get_neural_data(dataset='tang', return_raw=True, start_offset=80, end_offset=500)
# cc_max_all_neurons = cc_max(get_neural_data_per_trial(('042318', '043018','051018',)))
# assert cc_max_all_neurons.shape == (79,)

# %%
len(raw_data)
# Out:
# 2250

# %%
import numpy as np
# use first eight trials to get ccmax.
# each image at least has 8 trials. this will be a bit inaccurate but should be ok. with similar results as 
# a more proper way to get ccmax.
a = np.asarray([x[:8] for x in raw_data]).T

# %%
print(a.shape)  # (num_neuron x num_trial x num_time)
cc_max_all_neurons=cc_max(a)
assert cc_max_all_neurons.shape==(34,)
# Out:
# (34, 8, 2250)

# %%
f_main_result = join(dir_dict['analyses'], 'tang_refactored', '20201026', 'main_result_80,500.pkl')
if not exists(f_main_result):
    makedirs(dirname(f_main_result), exist_ok=True)
    df_main_result = collect_rcnn_k_bl_main_result(
        fixed_keys = {
        'kernel_size_l23': 3,
        'kernel_size_l1': 9,
        'ff_1st_block': True,
        'pooling_ksize': 3,
        'pooling_type': 'avg',
        'bn_after_fc': False,
        'rcnn_bl_psize': 1,
        'rcnn_bl_ptype': None,
        'input_size': 37,
        'split_seed': 'legacy',
        'dataset_prefix': 'tang',
        'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
        'scale_name': '0.01',
        'scale': '0.01',
        'smoothness_name': '0.000005',
        'smoothness': '0.000005',
        'additional_key': '80,500'
    },
        generator=chain(
            explored_models_20201026_tang_generator(with_source=True),
        ),
        total_num_param=27,
        train_size_mapping=dict(),
        cc_max_all_neurons=cc_max_all_neurons,
        num_neuron=34,
        skip_eval_json=True,
    )
    df_main_result.to_pickle(f_main_result)
    del df_main_result
df_main_result = pd.read_pickle(f_main_result)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700

# %%
df_main_result
# Out:
#                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350               0.192314
#                                                                                                   700               0.268044
#                                                                                                   1400              0.338834
#                                                                                      cm-last      350               0.192314
#                                                                                                   700               0.262054
# ...                                                                                                                      ...
# softplus True                 poisson   1          6         16          1           legacy       700               0.353030
#                                                                                                   1400              0.413476
#                                                              32          1           legacy       350               0.306843
#                                                                                                   700               0.369880
#                                                                                                   1400              0.433041
#
#                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350            0.175848
#                                                                                                   700            0.245612
#                                                                                                   1400           0.310576
#                                                                                      cm-last      350            0.175848
#                                                                                                   700            0.239894
# ...                                                                                                                   ...
# softplus True                 poisson   1          6         16          1           legacy       700            0.322137
#                                                                                                   1400           0.376611
#                                                              32          1           legacy       350            0.279864
#                                                                                                   700            0.337703
#                                                                                                   1400           0.394836
#
#                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350           0.380748
#                                                                                                   700           0.455340
#                                                                                                   1400          0.527054
#                                                                                      cm-last      350           0.380748
#                                                                                                   700           0.449850
# ...                                                                                                                  ...
# softplus True                 poisson   1          6         16          1           legacy       700           0.536787
#                                                                                                   1400          0.590986
#                                                              32          1           legacy       350           0.497244
#                                                                                                   700           0.553222
#                                                                                                   1400          0.609238
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350              4972
#                                                                                                   700              4972
#                                                                                                   1400             4972
#                                                                                      cm-last      350              4972
#                                                                                                   700              4972
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       700             16988
#                                                                                                   1400            16988
#                                                              32          1           legacy       350             53580
#                                                                                                   700             53580
#                                                                                                   1400            53580
#
# [4752 rows x 4 columns]

# %%
cc_max_all_neurons
# Out:
# array([0.96164626, 0.96911407, 0.9743023 , 0.97638917, 0.97134376,
#        0.9360377 , 0.9528313 , 0.9446178 , 0.9253463 , 0.9762265 ,
#        0.95276225, 0.9766284 , 0.9522268 , 0.9688639 , 0.97001046,
#        0.972969  , 0.7764594 , 0.93390423, 0.96687365, 0.9699098 ,
#        0.96331364, 0.9550133 , 0.9832062 , 0.9123864 , 0.9656663 ,
#        0.9324832 , 0.8520452 , 0.9781365 , 0.8961729 , 0.9805045 ,
#        0.96994597, 0.9573961 , 0.9801802 , 0.9641417 ], dtype=float32)
