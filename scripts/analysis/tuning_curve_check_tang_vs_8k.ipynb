# %%
import numpy as np

# %%
# load 8k data

# %%
from thesis_v2.data.prepared.yuanyuan_8k import get_neural_data

# %%
neural_data_8k = get_neural_data( ('042318', '043018', '051018'), scale=0.5)

# %%
neural_data_8k.shape
# Out:
# (8000, 79)

# %%
neural_data_8k = np.sort(neural_data_8k, axis=0)[::-1]

# %%
from thesis_v2.data.prepared.gaya import get_neural_data as get_neural_data_gaya

# %%
neural_data_tang_img = get_neural_data_gaya(post_scale=0.5, dataset='tang')

# %%
neural_data_tang_img.shape
# Out:
# (2250, 34)

# %%
neural_data_tang_img = np.sort(neural_data_tang_img, axis=0)[::-1]

# %%
# plot tuning curve for top 100

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def plot_tuning_curves(data):
    n, n_neuron = data.shape
    assert n_neuron <= 20
    plt.close('all')
    plt.plot(data)
    plt.show()

# %%
plot_tuning_curves(neural_data_8k[:50,:20])

# %%
plot_tuning_curves(neural_data_tang_img[:50, :20])
