# %% [markdown]
# this notebook makes sure that models with various setups (BN, act_fn) do have correct number of parameters and correct model structures and they can train.

# %%
import numpy as np

from thesis_v2.data.prepared.yuanyuan_8k import get_data

from thesis_v2.training_extra.maskcnn_like.opt import get_maskcnn_v1_opt_config
from thesis_v2.training_extra.maskcnn_like.training import (train_one,
                                                            partial)

from thesis_v2.models.maskcnn_polished.builder import (gen_maskcnn_polished, load_modules)
import json
from itertools import product
load_modules()

# keeping mean response at 0.5 seems the best. somehow. using batch norm is bad, somehow.
datasets_raw = get_data('a', 200, 50, ('042318', '043018', '051018'), scale=0.5)

datasets_raw = {
    'X_train': datasets_raw[0].astype(np.float32),
    'y_train': datasets_raw[1],
    'X_val': datasets_raw[2].astype(np.float32),
    'y_val': datasets_raw[3],
    'X_test': datasets_raw[4].astype(np.float32),
    'y_test': datasets_raw[5],
}





def do_something(*,
                 bn_before_act,
                 bn_after_fc,
                 act_fn,
                ):
    opt_config_partial = partial(get_maskcnn_v1_opt_config,
                                 scale=0.01,
                                 smoothness=0.00005,
                                 group=0.0)
    
    def gen_cnn_partial(input_size, n):
        a = gen_maskcnn_polished(input_size=input_size,
                                    num_neuron=n,
                                    out_channel=16,  # (try, 8, 16, 32, 48)
                                    kernel_size_l1=9,  # (try 5,9,13)
                                    kernel_size_l23=3,
                                    act_fn=act_fn,
                                    pooling_ksize=3,  # (try, 1,3,5,7)
                                    pooling_type='avg',  # try (avg, max)  # looks that max works well here?
                                    num_layer=2,
                                    bn_before_act=bn_before_act,
                                    bn_after_fc=bn_after_fc,
                                    )
        print(json.dumps(a, indent=2))
        return a
        

    r = train_one(arch_json_partial=gen_cnn_partial,
                       opt_config_partial=opt_config_partial,
                       datasets=datasets_raw,
                       key=f'debug/maskcnn_polished_check_alternative_setups/{bn_before_act}/{bn_after_fc}/{act_fn}',
                       show_every=10000,
                       max_epoch=100, # not meant to be fully run.
                       model_seed=0,
                       return_model=True)
    print(r['model'])
    print(r['stats_best']['stats']['test']['corr_mean'])

# %%
for bn_before_act_this, bn_after_fc_this, act_fn_this in product(
    [True, False], [True, False], ('softplus', 'relu'),
):
    print(bn_before_act_this, bn_after_fc_this, act_fn_this)
    do_something(bn_before_act=bn_before_act_this,
                bn_after_fc=bn_after_fc_this,
                 act_fn=act_fn_this,
                )
    # as a reference, my standard model has 20493 parameters.
# Out:
# True True softplus
# {
#   "module_dict": {
#     "bn_input": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 1,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv0": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 1,
#         "out_channels": 16,
#         "kernel_size": 9,
#         "padding": 0,
#         "bias": false
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn0": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "act0": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     },
#     "conv1": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 16,
#         "out_channels": 16,
#         "kernel_size": 3,
#         "padding": 1,
#         "bias": false
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn1": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "act1": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     },
#     "pooling": {
#       "name": "torch.nn.avgpool2d",
#       "params": {
#         "kernel_size": 3,
#         "ceil_mode": true
#       },
#       "init": null
#     },
#     "fc": {
#       "name": "maskcnn.factoredfc",
#       "params": {
#         "in_channels": 16,
#         "map_size": [
#           14,
#           14
#         ],
#         "out_features": 79,
#         "bias": false,
#         "weight_feature_constraint": null,
#         "weight_spatial_constraint": null
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn_output": {
#       "name": "torch.nn.batchnorm1d",
#       "params": {
#         "num_features": 79,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "final_act": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     }
#   },
#   "op_list": [
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "bn_input"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act1"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "input0",
#       "out": "feature_map"
#     },
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "pooling"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "fc"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn_output"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "final_act"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "feature_map",
#       "out": "out_neural"
#     }
#   ],
#   "out": [
#     "out_neural"
#   ],
#   "comments": {
#     "conv_layers": [
#       "conv0",
#       "conv1"
#     ]
#   }
# }
# num_param 20572
# ========starting phase 1/3==========
# val metric init {'loss': 0.8545389652252198, 'loss_no_reg': 0.844570517539978, 'corr': None, 'corr_mean': -0.008858012966811657, 'corr_mean_neg': 0.008858012966811657, 'corr2_mean': 0.0038518651854246855, 'corr2_mean_neg': -0.0038518651854246855, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8569158315658569
# train loss 0.8569158315658569
# val metric {'loss': 0.8537635564804077, 'loss_no_reg': 0.8445668816566467, 'corr': None, 'corr_mean': 0.027066827782641956, 'corr_mean_neg': -0.027066827782641956, 'corr2_mean': 0.005166340039989651, 'corr2_mean_neg': -0.005166340039989651, 'acc': None}
# test metric {'loss': 0.8545206870351519, 'loss_no_reg': 0.847032904624939, 'corr': None, 'corr_mean': 0.020519963844349207, 'corr_mean_neg': -0.020519963844349207, 'corr2_mean': 0.005085321598297271, 'corr2_mean_neg': -0.005085321598297271, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8355942368507385
# ========end phase 1/3==========
# ========starting phase 2/3==========
# for grp of sz 12, lr from 0.001000 to 0.000333
# val metric init {'loss': 0.8374376416206359, 'loss_no_reg': 0.8355942368507385, 'corr': None, 'corr_mean': 0.31361570954322815, 'corr_mean_neg': -0.31361570954322815, 'corr2_mean': 0.11344927549362183, 'corr2_mean_neg': -0.11344927549362183, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8332889676094055
# train loss 0.8332889676094055
# val metric {'loss': 0.836856234073639, 'loss_no_reg': 0.8350156545639038, 'corr': None, 'corr_mean': 0.3165723979473114, 'corr_mean_neg': -0.3165723979473114, 'corr2_mean': 0.11544698476791382, 'corr2_mean_neg': -0.11544698476791382, 'acc': None}
# test metric {'loss': 0.8371573431151254, 'loss_no_reg': 0.8374204039573669, 'corr': None, 'corr_mean': 0.3188512623310089, 'corr_mean_neg': -0.3188512623310089, 'corr2_mean': 0.1165844276547432, 'corr2_mean_neg': -0.1165844276547432, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8286469578742981
# ========end phase 2/3==========
# ========starting phase 3/3==========
# for grp of sz 12, lr from 0.000333 to 0.000111
# val metric init {'loss': 0.8303885340690613, 'loss_no_reg': 0.8286469578742981, 'corr': None, 'corr_mean': 0.34117206931114197, 'corr_mean_neg': -0.34117206931114197, 'corr2_mean': 0.13312625885009766, 'corr2_mean_neg': -0.13312625885009766, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8292932510375977
# train loss 0.8292932510375977
# val metric {'loss': 0.8303512215614319, 'loss_no_reg': 0.8286094069480896, 'corr': None, 'corr_mean': 0.34132543206214905, 'corr_mean_neg': -0.34132543206214905, 'corr2_mean': 0.1332317590713501, 'corr2_mean_neg': -0.1332317590713501, 'acc': None}
# test metric {'loss': 0.83028473172869, 'loss_no_reg': 0.8309346437454224, 'corr': None, 'corr_mean': 0.3440602123737335, 'corr_mean_neg': -0.3440602123737335, 'corr2_mean': 0.13499106466770172, 'corr2_mean_neg': -0.13499106466770172, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.827807605266571
# ========end phase 3/3==========
# JSONNet(
#   (moduledict): ModuleDict(
#     (act0): Softplus(beta=1, threshold=20)
#     (act1): Softplus(beta=1, threshold=20)
#     (bn0): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_input): BatchNorm2d(1, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_output): BatchNorm1d(79, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv0): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (fc): FactoredLinear2D()
#     (final_act): Softplus(beta=1, threshold=20)
#     (pooling): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   )
# )
# 0.3511947989463806
# True True relu
# {
#   "module_dict": {
#     "bn_input": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 1,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv0": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 1,
#         "out_channels": 16,
#         "kernel_size": 9,
#         "padding": 0,
#         "bias": false
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn0": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "act0": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     },
#     "conv1": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 16,
#         "out_channels": 16,
#         "kernel_size": 3,
#         "padding": 1,
#         "bias": false
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn1": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "act1": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     },
#     "pooling": {
#       "name": "torch.nn.avgpool2d",
#       "params": {
#         "kernel_size": 3,
#         "ceil_mode": true
#       },
#       "init": null
#     },
#     "fc": {
#       "name": "maskcnn.factoredfc",
#       "params": {
#         "in_channels": 16,
#         "map_size": [
#           14,
#           14
#         ],
#         "out_features": 79,
#         "bias": false,
#         "weight_feature_constraint": null,
#         "weight_spatial_constraint": null
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn_output": {
#       "name": "torch.nn.batchnorm1d",
#       "params": {
#         "num_features": 79,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "final_act": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     }
#   },
#   "op_list": [
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "bn_input"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act1"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "input0",
#       "out": "feature_map"
#     },
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "pooling"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "fc"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn_output"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "final_act"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "feature_map",
#       "out": "out_neural"
#     }
#   ],
#   "out": [
#     "out_neural"
#   ],
#   "comments": {
#     "conv_layers": [
#       "conv0",
#       "conv1"
#     ]
#   }
# }
# num_param 20572
# ========starting phase 1/3==========
# val metric init {'loss': 0.8545415163040161, 'loss_no_reg': 0.8445729613304138, 'corr': None, 'corr_mean': -0.005949108395725489, 'corr_mean_neg': 0.005949108395725489, 'corr2_mean': 0.0036176934372633696, 'corr2_mean_neg': -0.0036176934372633696, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8614892959594727
# train loss 0.8614892959594727
# val metric {'loss': 0.8541166424751282, 'loss_no_reg': 0.844563901424408, 'corr': None, 'corr_mean': 0.0026484683621674776, 'corr_mean_neg': -0.0026484683621674776, 'corr2_mean': 0.0046013821847736835, 'corr2_mean_neg': -0.0046013821847736835, 'acc': None}
# test metric {'loss': 0.8548778550965446, 'loss_no_reg': 0.8470322489738464, 'corr': None, 'corr_mean': 0.0058001186698675156, 'corr_mean_neg': -0.0058001186698675156, 'corr2_mean': 0.003909509163349867, 'corr2_mean_neg': -0.003909509163349867, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8367301821708679
# ========end phase 1/3==========
# ========starting phase 2/3==========
# for grp of sz 12, lr from 0.001000 to 0.000333
# val metric init {'loss': 0.8385625123977661, 'loss_no_reg': 0.8367301821708679, 'corr': None, 'corr_mean': 0.33294379711151123, 'corr_mean_neg': -0.33294379711151123, 'corr2_mean': 0.1254153698682785, 'corr2_mean_neg': -0.1254153698682785, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8320508599281311
# train loss 0.8320508599281311
# val metric {'loss': 0.8380900144577026, 'loss_no_reg': 0.8362612128257751, 'corr': None, 'corr_mean': 0.33449840545654297, 'corr_mean_neg': -0.33449840545654297, 'corr2_mean': 0.12657108902931213, 'corr2_mean_neg': -0.12657108902931213, 'acc': None}
# test metric {'loss': 0.8387245876448495, 'loss_no_reg': 0.8387371301651001, 'corr': None, 'corr_mean': 0.3337578773498535, 'corr_mean_neg': -0.3337578773498535, 'corr2_mean': 0.1265597939491272, 'corr2_mean_neg': -0.1265597939491272, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.82666015625
# ========end phase 2/3==========
# ========starting phase 3/3==========
# for grp of sz 12, lr from 0.000333 to 0.000111
# val metric init {'loss': 0.828356921672821, 'loss_no_reg': 0.82666015625, 'corr': None, 'corr_mean': 0.3790740668773651, 'corr_mean_neg': -0.3790740668773651, 'corr2_mean': 0.1590465009212494, 'corr2_mean_neg': -0.1590465009212494, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.827031135559082
# train loss 0.827031135559082
# val metric {'loss': 0.8282693505287171, 'loss_no_reg': 0.8265734910964966, 'corr': None, 'corr_mean': 0.3793905973434448, 'corr_mean_neg': -0.3793905973434448, 'corr2_mean': 0.15930578112602234, 'corr2_mean_neg': -0.15930578112602234, 'acc': None}
# test metric {'loss': 0.8288382972989764, 'loss_no_reg': 0.8293721675872803, 'corr': None, 'corr_mean': 0.37742239236831665, 'corr_mean_neg': -0.37742239236831665, 'corr2_mean': 0.15894918143749237, 'corr2_mean_neg': -0.15894918143749237, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8254965543746948
# ========end phase 3/3==========
# JSONNet(
#   (moduledict): ModuleDict(
#     (act0): ReLU()
#     (act1): ReLU()
#     (bn0): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_input): BatchNorm2d(1, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_output): BatchNorm1d(79, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv0): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (fc): FactoredLinear2D()
#     (final_act): ReLU()
#     (pooling): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   )
# )
# 0.3864126205444336
# True False softplus
# {
#   "module_dict": {
#     "bn_input": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 1,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv0": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 1,
#         "out_channels": 16,
#         "kernel_size": 9,
#         "padding": 0,
#         "bias": false
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn0": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "act0": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     },
#     "conv1": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 16,
#         "out_channels": 16,
#         "kernel_size": 3,
#         "padding": 1,
#         "bias": false
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn1": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "act1": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     },
#     "pooling": {
#       "name": "torch.nn.avgpool2d",
#       "params": {
#         "kernel_size": 3,
#         "ceil_mode": true
#       },
#       "init": null
#     },
#     "fc": {
#       "name": "maskcnn.factoredfc",
#       "params": {
#         "in_channels": 16,
#         "map_size": [
#           14,
#           14
#         ],
#         "out_features": 79,
#         "bias": true,
#         "weight_feature_constraint": null,
#         "weight_spatial_constraint": null
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "final_act": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     }
#   },
#   "op_list": [
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "bn_input"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act1"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "input0",
#       "out": "feature_map"
#     },
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "pooling"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "fc"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "final_act"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "feature_map",
#       "out": "out_neural"
#     }
#   ],
#   "out": [
#     "out_neural"
#   ],
#   "comments": {
#     "conv_layers": [
#       "conv0",
#       "conv1"
#     ]
#   }
# }
# num_param 20493
# ========starting phase 1/3==========
# val metric init {'loss': 0.8547293186187744, 'loss_no_reg': 0.8445666432380676, 'corr': None, 'corr_mean': 0.013066182844340801, 'corr_mean_neg': -0.013066182844340801, 'corr2_mean': 0.003972372505813837, 'corr2_mean_neg': -0.003972372505813837, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8566426038742065
# train loss 0.8566426038742065
# val metric {'loss': 0.8536338090896607, 'loss_no_reg': 0.8445668816566467, 'corr': None, 'corr_mean': 0.017946824853609114, 'corr_mean_neg': -0.017946824853609114, 'corr2_mean': 0.004240613672544528, 'corr2_mean_neg': -0.004240613672544528, 'acc': None}
# test metric {'loss': 0.8543940356799534, 'loss_no_reg': 0.8470348119735718, 'corr': None, 'corr_mean': 0.01305061870802023, 'corr_mean_neg': -0.01305061870802023, 'corr2_mean': 0.0034984383103906763, 'corr2_mean_neg': -0.0034984383103906763, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.841401994228363
# ========end phase 1/3==========
# ========starting phase 2/3==========
# for grp of sz 11, lr from 0.001000 to 0.000333
# val metric init {'loss': 0.8430867314338684, 'loss_no_reg': 0.841401994228363, 'corr': None, 'corr_mean': 0.159469859503634, 'corr_mean_neg': -0.159469859503634, 'corr2_mean': 0.038795827345198354, 'corr2_mean_neg': -0.038795827345198354, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8448331952095032
# train loss 0.8448331952095032
# val metric {'loss': 0.8430509924888611, 'loss_no_reg': 0.8413587212562561, 'corr': None, 'corr_mean': 0.1584426986489775, 'corr_mean_neg': -0.1584426986489775, 'corr2_mean': 0.03870862755020416, 'corr2_mean_neg': -0.03870862755020416, 'acc': None}
# test metric {'loss': 0.8433747206415448, 'loss_no_reg': 0.8437454104423523, 'corr': None, 'corr_mean': 0.15687696114064584, 'corr_mean_neg': -0.15687696114064584, 'corr2_mean': 0.038345173158297684, 'corr2_mean_neg': -0.038345173158297684, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8399950265884399
# ========end phase 2/3==========
# ========starting phase 3/3==========
# for grp of sz 11, lr from 0.000333 to 0.000111
# val metric init {'loss': 0.8421354174613953, 'loss_no_reg': 0.8399950265884399, 'corr': None, 'corr_mean': 0.1894105882914383, 'corr_mean_neg': -0.1894105882914383, 'corr2_mean': 0.053965267705462366, 'corr2_mean_neg': -0.053965267705462366, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8441876769065857
# train loss 0.8441876769065857
# val metric {'loss': 0.8420949697494506, 'loss_no_reg': 0.8399515151977539, 'corr': None, 'corr_mean': 0.189067386915978, 'corr_mean_neg': -0.189067386915978, 'corr2_mean': 0.05378369110861028, 'corr2_mean_neg': -0.05378369110861028, 'acc': None}
# test metric {'loss': 0.8424391235624041, 'loss_no_reg': 0.8423449993133545, 'corr': None, 'corr_mean': 0.18867079890038393, 'corr_mean_neg': -0.18867079890038393, 'corr2_mean': 0.05355377561340672, 'corr2_mean_neg': -0.05355377561340672, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.839191734790802
# ========end phase 3/3==========
# JSONNet(
#   (moduledict): ModuleDict(
#     (act0): Softplus(beta=1, threshold=20)
#     (act1): Softplus(beta=1, threshold=20)
#     (bn0): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_input): BatchNorm2d(1, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv0): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (fc): FactoredLinear2D()
#     (final_act): Softplus(beta=1, threshold=20)
#     (pooling): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   )
# )
# 0.19366464636559727
# True False relu
# {
#   "module_dict": {
#     "bn_input": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 1,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv0": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 1,
#         "out_channels": 16,
#         "kernel_size": 9,
#         "padding": 0,
#         "bias": false
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn0": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "act0": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     },
#     "conv1": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 16,
#         "out_channels": 16,
#         "kernel_size": 3,
#         "padding": 1,
#         "bias": false
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn1": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "act1": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     },
#     "pooling": {
#       "name": "torch.nn.avgpool2d",
#       "params": {
#         "kernel_size": 3,
#         "ceil_mode": true
#       },
#       "init": null
#     },
#     "fc": {
#       "name": "maskcnn.factoredfc",
#       "params": {
#         "in_channels": 16,
#         "map_size": [
#           14,
#           14
#         ],
#         "out_features": 79,
#         "bias": true,
#         "weight_feature_constraint": null,
#         "weight_spatial_constraint": null
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "final_act": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     }
#   },
#   "op_list": [
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "bn_input"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act1"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "input0",
#       "out": "feature_map"
#     },
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "pooling"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "fc"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "final_act"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "feature_map",
#       "out": "out_neural"
#     }
#   ],
#   "out": [
#     "out_neural"
#   ],
#   "comments": {
#     "conv_layers": [
#       "conv0",
#       "conv1"
#     ]
#   }
# }
# num_param 20493
# ========starting phase 1/3==========
# val metric init {'loss': 0.854728901386261, 'loss_no_reg': 0.8445661664009094, 'corr': None, 'corr_mean': 0.009577998891472816, 'corr_mean_neg': -0.009577998891472816, 'corr2_mean': 0.0038507208228111267, 'corr2_mean_neg': -0.0038507208228111267, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8566394448280334
# train loss 0.8566394448280334
# val metric {'loss': 0.8536543607711792, 'loss_no_reg': 0.8445637226104736, 'corr': None, 'corr_mean': 0.01739002950489521, 'corr_mean_neg': -0.01739002950489521, 'corr2_mean': 0.004689482972025871, 'corr2_mean_neg': -0.004689482972025871, 'acc': None}
# test metric {'loss': 0.854415740285601, 'loss_no_reg': 0.8470339179039001, 'corr': None, 'corr_mean': 0.018066981807351112, 'corr_mean_neg': -0.018066981807351112, 'corr2_mean': 0.004110764246433973, 'corr2_mean_neg': -0.004110764246433973, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8363021612167358
# ========end phase 1/3==========
# ========starting phase 2/3==========
# for grp of sz 11, lr from 0.001000 to 0.000333
# val metric init {'loss': 0.8389845132827759, 'loss_no_reg': 0.8363021612167358, 'corr': None, 'corr_mean': 0.26835155487060547, 'corr_mean_neg': -0.26835155487060547, 'corr2_mean': 0.08515932410955429, 'corr2_mean_neg': -0.08515932410955429, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8397374153137207
# train loss 0.8397374153137207
# val metric {'loss': 0.8388372182846069, 'loss_no_reg': 0.8361521363258362, 'corr': None, 'corr_mean': 0.2694753110408783, 'corr_mean_neg': -0.2694753110408783, 'corr2_mean': 0.0858403667807579, 'corr2_mean_neg': -0.0858403667807579, 'acc': None}
# test metric {'loss': 0.8390965035983494, 'loss_no_reg': 0.8384382128715515, 'corr': None, 'corr_mean': 0.2649715840816498, 'corr_mean_neg': -0.2649715840816498, 'corr2_mean': 0.08390925824642181, 'corr2_mean_neg': -0.08390925824642181, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8334897756576538
# ========end phase 2/3==========
# ========starting phase 3/3==========
# for grp of sz 11, lr from 0.000333 to 0.000111
# val metric init {'loss': 0.8363590598106384, 'loss_no_reg': 0.8334897756576538, 'corr': None, 'corr_mean': 0.31079691648483276, 'corr_mean_neg': -0.31079691648483276, 'corr2_mean': 0.11054021865129471, 'corr2_mean_neg': -0.11054021865129471, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8372437953948975
# train loss 0.8372437953948975
# val metric {'loss': 0.8362471222877502, 'loss_no_reg': 0.8333751559257507, 'corr': None, 'corr_mean': 0.3107372522354126, 'corr_mean_neg': -0.3107372522354126, 'corr2_mean': 0.110524483025074, 'corr2_mean_neg': -0.110524483025074, 'acc': None}
# test metric {'loss': 0.8367264441081456, 'loss_no_reg': 0.8359322547912598, 'corr': None, 'corr_mean': 0.306728333234787, 'corr_mean_neg': -0.306728333234787, 'corr2_mean': 0.10844281315803528, 'corr2_mean_neg': -0.10844281315803528, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8322732448577881
# ========end phase 3/3==========
# JSONNet(
#   (moduledict): ModuleDict(
#     (act0): ReLU()
#     (act1): ReLU()
#     (bn0): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_input): BatchNorm2d(1, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv0): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (fc): FactoredLinear2D()
#     (final_act): ReLU()
#     (pooling): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   )
# )
# 0.31663039326667786
# False True softplus
# {
#   "module_dict": {
#     "bn_input": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 1,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv0": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 1,
#         "out_channels": 16,
#         "kernel_size": 9,
#         "padding": 0,
#         "bias": true
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "act0": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     },
#     "bn0": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv1": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 16,
#         "out_channels": 16,
#         "kernel_size": 3,
#         "padding": 1,
#         "bias": true
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "act1": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     },
#     "bn1": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "pooling": {
#       "name": "torch.nn.avgpool2d",
#       "params": {
#         "kernel_size": 3,
#         "ceil_mode": true
#       },
#       "init": null
#     },
#     "fc": {
#       "name": "maskcnn.factoredfc",
#       "params": {
#         "in_channels": 16,
#         "map_size": [
#           14,
#           14
#         ],
#         "out_features": 79,
#         "bias": false,
#         "weight_feature_constraint": null,
#         "weight_spatial_constraint": null
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn_output": {
#       "name": "torch.nn.batchnorm1d",
#       "params": {
#         "num_features": 79,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "final_act": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     }
#   },
#   "op_list": [
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "bn_input"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn1"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "input0",
#       "out": "feature_map"
#     },
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "pooling"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "fc"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn_output"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "final_act"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "feature_map",
#       "out": "out_neural"
#     }
#   ],
#   "out": [
#     "out_neural"
#   ],
#   "comments": {
#     "conv_layers": [
#       "conv0",
#       "conv1"
#     ]
#   }
# }
# num_param 20604
# ========starting phase 1/3==========
# val metric init {'loss': 0.8545753836631775, 'loss_no_reg': 0.8445719480514526, 'corr': None, 'corr_mean': 0.001205069595016539, 'corr_mean_neg': -0.001205069595016539, 'corr2_mean': 0.004680489655584097, 'corr2_mean_neg': -0.004680489655584097, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.858921229839325
# train loss 0.858921229839325
# val metric {'loss': 0.8541263699531555, 'loss_no_reg': 0.8445631861686707, 'corr': None, 'corr_mean': 0.009021638143996272, 'corr_mean_neg': -0.009021638143996272, 'corr2_mean': 0.007178040536804808, 'corr2_mean_neg': -0.007178040536804808, 'acc': None}
# test metric {'loss': 0.8548875791685921, 'loss_no_reg': 0.8470330238342285, 'corr': None, 'corr_mean': 0.00813117259052358, 'corr_mean_neg': -0.00813117259052358, 'corr2_mean': 0.0061167708455760784, 'corr2_mean_neg': -0.0061167708455760784, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8362271189689636
# ========end phase 1/3==========
# ========starting phase 2/3==========
# for grp of sz 14, lr from 0.001000 to 0.000333
# val metric init {'loss': 0.8377232789993286, 'loss_no_reg': 0.8362271189689636, 'corr': None, 'corr_mean': 0.2693317234516144, 'corr_mean_neg': -0.2693317234516144, 'corr2_mean': 0.08761169761419296, 'corr2_mean_neg': -0.08761169761419296, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8358685970306396
# train loss 0.8358685970306396
# val metric {'loss': 0.8374315738677979, 'loss_no_reg': 0.8359399437904358, 'corr': None, 'corr_mean': 0.2699219286441803, 'corr_mean_neg': -0.2699219286441803, 'corr2_mean': 0.08796270936727524, 'corr2_mean_neg': -0.08796270936727524, 'acc': None}
# test metric {'loss': 0.83784191097532, 'loss_no_reg': 0.8385098576545715, 'corr': None, 'corr_mean': 0.2681424021720886, 'corr_mean_neg': -0.2681424021720886, 'corr2_mean': 0.08726885914802551, 'corr2_mean_neg': -0.08726885914802551, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8316460251808167
# ========end phase 2/3==========
# ========starting phase 3/3==========
# for grp of sz 14, lr from 0.000333 to 0.000111
# val metric init {'loss': 0.8329303383827209, 'loss_no_reg': 0.8316460251808167, 'corr': None, 'corr_mean': 0.2950252890586853, 'corr_mean_neg': -0.2950252890586853, 'corr2_mean': 0.10229061543941498, 'corr2_mean_neg': -0.10229061543941498, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8326494693756104
# train loss 0.8326494693756104
# val metric {'loss': 0.8328867197036743, 'loss_no_reg': 0.8316026926040649, 'corr': None, 'corr_mean': 0.2955341637134552, 'corr_mean_neg': -0.2955341637134552, 'corr2_mean': 0.102603480219841, 'corr2_mean_neg': -0.102603480219841, 'acc': None}
# test metric {'loss': 0.8329626492091587, 'loss_no_reg': 0.8340970873832703, 'corr': None, 'corr_mean': 0.2973332107067108, 'corr_mean_neg': -0.2973332107067108, 'corr2_mean': 0.10364028811454773, 'corr2_mean_neg': -0.10364028811454773, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8309401869773865
# ========end phase 3/3==========
# JSONNet(
#   (moduledict): ModuleDict(
#     (act0): Softplus(beta=1, threshold=20)
#     (act1): Softplus(beta=1, threshold=20)
#     (bn0): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_input): BatchNorm2d(1, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_output): BatchNorm1d(79, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv0): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1))
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fc): FactoredLinear2D()
#     (final_act): Softplus(beta=1, threshold=20)
#     (pooling): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   )
# )
# 0.30653154850006104
# False True relu
# {
#   "module_dict": {
#     "bn_input": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 1,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv0": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 1,
#         "out_channels": 16,
#         "kernel_size": 9,
#         "padding": 0,
#         "bias": true
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "act0": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     },
#     "bn0": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv1": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 16,
#         "out_channels": 16,
#         "kernel_size": 3,
#         "padding": 1,
#         "bias": true
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "act1": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     },
#     "bn1": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "pooling": {
#       "name": "torch.nn.avgpool2d",
#       "params": {
#         "kernel_size": 3,
#         "ceil_mode": true
#       },
#       "init": null
#     },
#     "fc": {
#       "name": "maskcnn.factoredfc",
#       "params": {
#         "in_channels": 16,
#         "map_size": [
#           14,
#           14
#         ],
#         "out_features": 79,
#         "bias": false,
#         "weight_feature_constraint": null,
#         "weight_spatial_constraint": null
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "bn_output": {
#       "name": "torch.nn.batchnorm1d",
#       "params": {
#         "num_features": 79,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "final_act": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     }
#   },
#   "op_list": [
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "bn_input"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn1"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "input0",
#       "out": "feature_map"
#     },
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "pooling"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "fc"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn_output"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "final_act"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "feature_map",
#       "out": "out_neural"
#     }
#   ],
#   "out": [
#     "out_neural"
#   ],
#   "comments": {
#     "conv_layers": [
#       "conv0",
#       "conv1"
#     ]
#   }
# }
# num_param 20604
# ========starting phase 1/3==========
# val metric init {'loss': 0.8545833945274353, 'loss_no_reg': 0.8445799946784973, 'corr': None, 'corr_mean': -0.002196677029132843, 'corr_mean_neg': 0.002196677029132843, 'corr2_mean': 0.004477942828088999, 'corr2_mean_neg': -0.004477942828088999, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8768617510795593
# train loss 0.8768617510795593
# val metric {'loss': 0.8544126272201538, 'loss_no_reg': 0.8445687294006348, 'corr': None, 'corr_mean': -0.0019830395467579365, 'corr_mean_neg': 0.0019830395467579365, 'corr2_mean': 0.004469791892915964, 'corr2_mean_neg': -0.004469791892915964, 'acc': None}
# test metric {'loss': 0.855166860989162, 'loss_no_reg': 0.8470287919044495, 'corr': None, 'corr_mean': 0.004962565377354622, 'corr_mean_neg': -0.004962565377354622, 'corr2_mean': 0.003973884508013725, 'corr2_mean_neg': -0.003973884508013725, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8392715454101562
# ========end phase 1/3==========
# ========starting phase 2/3==========
# for grp of sz 14, lr from 0.001000 to 0.000333
# val metric init {'loss': 0.8421927332878113, 'loss_no_reg': 0.8392715454101562, 'corr': None, 'corr_mean': 0.2677591145038605, 'corr_mean_neg': -0.2677591145038605, 'corr2_mean': 0.08841968327760696, 'corr2_mean_neg': -0.08841968327760696, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8379603028297424
# train loss 0.8379603028297424
# val metric {'loss': 0.8417660117149353, 'loss_no_reg': 0.8388570547103882, 'corr': None, 'corr_mean': 0.27082303166389465, 'corr_mean_neg': -0.27082303166389465, 'corr2_mean': 0.08998856693506241, 'corr2_mean_neg': -0.08998856693506241, 'acc': None}
# test metric {'loss': 0.8422899757112775, 'loss_no_reg': 0.841249406337738, 'corr': None, 'corr_mean': 0.2728033661842346, 'corr_mean_neg': -0.2728033661842346, 'corr2_mean': 0.09038567543029785, 'corr2_mean_neg': -0.09038567543029785, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8275705575942993
# ========end phase 2/3==========
# ========starting phase 3/3==========
# for grp of sz 14, lr from 0.000333 to 0.000111
# val metric init {'loss': 0.8300562977790833, 'loss_no_reg': 0.8275705575942993, 'corr': None, 'corr_mean': 0.3699797987937927, 'corr_mean_neg': -0.3699797987937927, 'corr2_mean': 0.153690904378891, 'corr2_mean_neg': -0.153690904378891, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8299691677093506
# train loss 0.8299691677093506
# val metric {'loss': 0.8299132108688354, 'loss_no_reg': 0.8274296522140503, 'corr': None, 'corr_mean': 0.3711583912372589, 'corr_mean_neg': -0.3711583912372589, 'corr2_mean': 0.15465624630451202, 'corr2_mean_neg': -0.15465624630451202, 'acc': None}
# test metric {'loss': 0.8303258333887372, 'loss_no_reg': 0.8301461338996887, 'corr': None, 'corr_mean': 0.3701440691947937, 'corr_mean_neg': -0.3701440691947937, 'corr2_mean': 0.15452605485916138, 'corr2_mean_neg': -0.15452605485916138, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8254662752151489
# ========end phase 3/3==========
# JSONNet(
#   (moduledict): ModuleDict(
#     (act0): ReLU()
# ...
#     (bn_output): BatchNorm1d(79, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv0): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1))
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fc): FactoredLinear2D()
#     (final_act): ReLU()
#     (pooling): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   )
# )
# 0.38972169160842896
# False False softplus
# {
#   "module_dict": {
#     "bn_input": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 1,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv0": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 1,
#         "out_channels": 16,
#         "kernel_size": 9,
#         "padding": 0,
#         "bias": true
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "act0": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     },
#     "bn0": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv1": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 16,
#         "out_channels": 16,
#         "kernel_size": 3,
#         "padding": 1,
#         "bias": true
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "act1": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     },
#     "bn1": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "pooling": {
#       "name": "torch.nn.avgpool2d",
#       "params": {
#         "kernel_size": 3,
#         "ceil_mode": true
#       },
#       "init": null
#     },
#     "fc": {
#       "name": "maskcnn.factoredfc",
#       "params": {
#         "in_channels": 16,
#         "map_size": [
#           14,
#           14
#         ],
#         "out_features": 79,
#         "bias": true,
#         "weight_feature_constraint": null,
#         "weight_spatial_constraint": null
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "final_act": {
#       "name": "torch.nn.softplus",
#       "params": {},
#       "init": null
#     }
#   },
#   "op_list": [
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "bn_input"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn1"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "input0",
#       "out": "feature_map"
#     },
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "pooling"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "fc"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "final_act"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "feature_map",
#       "out": "out_neural"
#     }
#   ],
#   "out": [
#     "out_neural"
#   ],
#   "comments": {
#     "conv_layers": [
#       "conv0",
#       "conv1"
#     ]
#   }
# }
# num_param 20525
# ========starting phase 1/3==========
# val metric init {'loss': 0.854637861251831, 'loss_no_reg': 0.8445671200752258, 'corr': None, 'corr_mean': 0.009111088700592518, 'corr_mean_neg': -0.009111088700592518, 'corr2_mean': 0.005741142202168703, 'corr2_mean_neg': -0.005741142202168703, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8565607070922852
# train loss 0.8565607070922852
# val metric {'loss': 0.8535412788391114, 'loss_no_reg': 0.8445680737495422, 'corr': None, 'corr_mean': 0.013107021279556418, 'corr_mean_neg': -0.013107021279556418, 'corr2_mean': 0.004955031472939116, 'corr2_mean_neg': -0.004955031472939116, 'acc': None}
# test metric {'loss': 0.8542976719992501, 'loss_no_reg': 0.847032368183136, 'corr': None, 'corr_mean': 0.017776864312612748, 'corr_mean_neg': -0.017776864312612748, 'corr2_mean': 0.004796033896387075, 'corr2_mean_neg': -0.004796033896387075, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8373522162437439
# ========end phase 1/3==========
# ========starting phase 2/3==========
# for grp of sz 13, lr from 0.001000 to 0.000333
# val metric init {'loss': 0.840096628665924, 'loss_no_reg': 0.8373522162437439, 'corr': None, 'corr_mean': 0.22268304228782654, 'corr_mean_neg': -0.22268304228782654, 'corr2_mean': 0.06322436034679413, 'corr2_mean_neg': -0.06322436034679413, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8417710661888123
# train loss 0.8417710661888123
# val metric {'loss': 0.8400315403938293, 'loss_no_reg': 0.8372879028320312, 'corr': None, 'corr_mean': 0.2250615805387497, 'corr_mean_neg': -0.2250615805387497, 'corr2_mean': 0.06443274021148682, 'corr2_mean_neg': -0.06443274021148682, 'acc': None}
# test metric {'loss': 0.8401417987687247, 'loss_no_reg': 0.8396700024604797, 'corr': None, 'corr_mean': 0.22183401882648468, 'corr_mean_neg': -0.22183401882648468, 'corr2_mean': 0.06336531043052673, 'corr2_mean_neg': -0.06336531043052673, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8356146812438965
# ========end phase 2/3==========
# ========starting phase 3/3==========
# for grp of sz 13, lr from 0.000333 to 0.000111
# val metric init {'loss': 0.8384275555610656, 'loss_no_reg': 0.8356146812438965, 'corr': None, 'corr_mean': 0.2549826502799988, 'corr_mean_neg': -0.2549826502799988, 'corr2_mean': 0.07975511997938156, 'corr2_mean_neg': -0.07975511997938156, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8404800891876221
# train loss 0.8404800891876221
# val metric {'loss': 0.8384282469749451, 'loss_no_reg': 0.8356153964996338, 'corr': None, 'corr_mean': 0.2550466060638428, 'corr_mean_neg': -0.2550466060638428, 'corr2_mean': 0.07979422062635422, 'corr2_mean_neg': -0.07979422062635422, 'acc': None}
# test metric {'loss': 0.8385710545948574, 'loss_no_reg': 0.8380202651023865, 'corr': None, 'corr_mean': 0.2543041706085205, 'corr_mean_neg': -0.2543041706085205, 'corr2_mean': 0.07897321879863739, 'corr2_mean_neg': -0.07897321879863739, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8352594971656799
# ========end phase 3/3==========
# JSONNet(
#   (moduledict): ModuleDict(
#     (act0): Softplus(beta=1, threshold=20)
#     (act1): Softplus(beta=1, threshold=20)
#     (bn0): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_input): BatchNorm2d(1, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv0): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1))
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fc): FactoredLinear2D()
#     (final_act): Softplus(beta=1, threshold=20)
#     (pooling): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   )
# )
# 0.25901198387145996
# False False relu
# {
#   "module_dict": {
#     "bn_input": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 1,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv0": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 1,
#         "out_channels": 16,
#         "kernel_size": 9,
#         "padding": 0,
#         "bias": true
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "act0": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     },
#     "bn0": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "conv1": {
#       "name": "torch.nn.conv2d",
#       "params": {
#         "in_channels": 16,
#         "out_channels": 16,
#         "kernel_size": 3,
#         "padding": 1,
#         "bias": true
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "act1": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     },
#     "bn1": {
#       "name": "torch.nn.batchnorm2d",
#       "params": {
#         "num_features": 16,
#         "eps": 0.001,
#         "momentum": 0.1,
#         "affine": true
#       },
#       "init": {}
#     },
#     "pooling": {
#       "name": "torch.nn.avgpool2d",
#       "params": {
#         "kernel_size": 3,
#         "ceil_mode": true
#       },
#       "init": null
#     },
#     "fc": {
#       "name": "maskcnn.factoredfc",
#       "params": {
#         "in_channels": 16,
#         "map_size": [
#           14,
#           14
#         ],
#         "out_features": 79,
#         "bias": true,
#         "weight_feature_constraint": null,
#         "weight_spatial_constraint": null
#       },
#       "init": {
#         "strategy": "normal",
#         "parameters": {
#           "std": 0.01
#         }
#       }
#     },
#     "final_act": {
#       "name": "torch.nn.relu",
#       "params": {},
#       "init": null
#     }
#   },
#   "op_list": [
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "bn_input"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn0"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "conv1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "act1"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "bn1"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "input0",
#       "out": "feature_map"
#     },
#     {
#       "name": "sequential",
#       "args": [
#         [
#           {
#             "name": "module",
#             "args": [
#               "pooling"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "fc"
#             ],
#             "kwargs": {}
#           },
#           {
#             "name": "module",
#             "args": [
#               "final_act"
#             ],
#             "kwargs": {}
#           }
#         ]
#       ],
#       "kwargs": {},
#       "in": "feature_map",
#       "out": "out_neural"
#     }
#   ],
#   "out": [
#     "out_neural"
#   ],
#   "comments": {
#     "conv_layers": [
#       "conv0",
#       "conv1"
#     ]
#   }
# }
# num_param 20525
# ========starting phase 1/3==========
# val metric init {'loss': 0.8546382069587708, 'loss_no_reg': 0.8445674180984497, 'corr': None, 'corr_mean': 0.0092448266223073, 'corr_mean_neg': -0.0092448266223073, 'corr2_mean': 0.004861724562942982, 'corr2_mean_neg': -0.004861724562942982, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8565621376037598
# train loss 0.8565621376037598
# val metric {'loss': 0.8536009430885315, 'loss_no_reg': 0.8445635437965393, 'corr': None, 'corr_mean': 0.015803467482328415, 'corr_mean_neg': -0.015803467482328415, 'corr2_mean': 0.006029975134879351, 'corr2_mean_neg': -0.006029975134879351, 'acc': None}
# test metric {'loss': 0.8543622834341866, 'loss_no_reg': 0.8470334410667419, 'corr': None, 'corr_mean': 0.01996075175702572, 'corr_mean_neg': -0.01996075175702572, 'corr2_mean': 0.0060811350122094154, 'corr2_mean_neg': -0.0060811350122094154, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.833069384098053
# ========end phase 1/3==========
# ========starting phase 2/3==========
# for grp of sz 13, lr from 0.001000 to 0.000333
# val metric init {'loss': 0.8357696294784546, 'loss_no_reg': 0.833069384098053, 'corr': None, 'corr_mean': 0.307798832654953, 'corr_mean_neg': -0.307798832654953, 'corr2_mean': 0.10836860537528992, 'corr2_mean_neg': -0.10836860537528992, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.836175262928009
# train loss 0.836175262928009
# val metric {'loss': 0.8356287360191346, 'loss_no_reg': 0.8329221606254578, 'corr': None, 'corr_mean': 0.3079926073551178, 'corr_mean_neg': -0.3079926073551178, 'corr2_mean': 0.1084374412894249, 'corr2_mean_neg': -0.1084374412894249, 'acc': None}
# test metric {'loss': 0.8358314377920968, 'loss_no_reg': 0.8354160189628601, 'corr': None, 'corr_mean': 0.3054891526699066, 'corr_mean_neg': -0.3054891526699066, 'corr2_mean': 0.10721936821937561, 'corr2_mean_neg': -0.10721936821937561, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8301353454589844
# ========end phase 2/3==========
# ========starting phase 3/3==========
# for grp of sz 13, lr from 0.000333 to 0.000111
# val metric init {'loss': 0.8328818321228028, 'loss_no_reg': 0.8301353454589844, 'corr': None, 'corr_mean': 0.34244388341903687, 'corr_mean_neg': -0.34244388341903687, 'corr2_mean': 0.13094094395637512, 'corr2_mean_neg': -0.13094094395637512, 'acc': None}
# ========starting epoch 0==========
# 0-0, train loss 0.8342518210411072
# train loss 0.8342518210411072
# val metric {'loss': 0.8327718853950501, 'loss_no_reg': 0.8300266861915588, 'corr': None, 'corr_mean': 0.343205064535141, 'corr_mean_neg': -0.343205064535141, 'corr2_mean': 0.1315416544675827, 'corr2_mean_neg': -0.1315416544675827, 'acc': None}
# test metric {'loss': 0.8330811006682259, 'loss_no_reg': 0.8326367735862732, 'corr': None, 'corr_mean': 0.3420073390007019, 'corr_mean_neg': -0.3420073390007019, 'corr2_mean': 0.13165050745010376, 'corr2_mean_neg': -0.13165050745010376, 'acc': None}
# ========done epoch 0==========
# recover best model after 100 epochs metric 0.8290277123451233
# ========end phase 3/3==========
# JSONNet(
#   (moduledict): ModuleDict(
#     (act0): ReLU()
#     (act1): ReLU()
#     (bn0): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (bn_input): BatchNorm2d(1, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv0): Conv2d(1, 16, kernel_size=(9, 9), stride=(1, 1))
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fc): FactoredLinear2D()
#     (final_act): ReLU()
#     (pooling): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   )
# )
# 0.34681108593940735
