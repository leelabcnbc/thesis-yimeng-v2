# %%
import numpy as np
import matplotlib.pyplot as plt
from os.path import join
from thesis_v2.data.prepared import tang_v1
from thesis_v2 import dir_dict

# %%
global_dict = {
    'img_path': join(dir_dict['private_data'], 'tang_v1', 'images',),
    'rsp_path': join(dir_dict['private_data'], 'tang_v1', 'neural',),
    'num_img_train': 34000,
    'num_img_val': 1000,
    'num_neurons_total': 302,
    # neurons with responses to
    'num_neurons_with_response_to_all_images': 302,
#     'num_trial': 4,
}

# %%
x_train = np.load(join(global_dict['img_path'], 'trainPic_m3s1.npy'))

# %%
x_train.shape
plt.imshow(x_train[100], cmap='gray')

# %%
train_img100 = tang_v1.images(x_train, px_kept=100, final_size=50)
train_img80 = tang_v1.images(x_train)

# %%
plt.imshow(train_img100[100][0],cmap='gray')

# %%
plt.imshow(train_img80[100][0], cmap='gray')

# %%
y_train, y_val = tang_v1.get_neural_data('m3s1')

# %%
y_val.shape
# Out:
# (1000, 324)

# %%
from scipy.io import loadmat
from strflab.stats import cc_max

data = loadmat(join(dir_dict['private_data'], 'V1_Data', 'M160607', 
                    'Site1', 'val', 'SRsp.mat'))['SRsp']
data = data.transpose((0, 2, 1))
data.shape
# Out:
# (326, 10, 1000)

# %%
from thesis_v2.analysis.tang_v1 import load_ccmax_m3s1

load_ccmax_m3s1().shape
# Out:
# (324,)
