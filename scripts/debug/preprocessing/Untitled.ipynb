# %%
import numpy as np
from thesis_v2.data.prepared.yuanyuan_8k import get_neural_data_per_trial
from thesis_v2.data.prepared.cadena_plos_cb19 import get_raw_pkl

# %%
data = get_neural_data_per_trial(('042318', '043018', '051018',))
v1_ind = np.array([8, 9, 10, 11, 12, 13, 14, 18, 34, 35, 36, 37, 38, 39, 40, 
                       45, 54, 60, 61, 62, 63, 64, 65, 66, 68])
data[v1_ind].shape
# Out:
# (25, 6, 8000)

# %%
response_all = get_raw_pkl()['responses']
good_index = np.logical_not(np.any(np.all(np.isnan(response_all), axis=0), axis=0))
good_index
bad_index = np.any(np.all(np.isnan(response_all), axis=0), axis=0)
response_sec = response_all[:, :, bad_index]
response_sec.shape
# Out:
# (4, 7250, 51)

# %%
np.all(np.any(np.logical_not(np.isnan(response_sec)), axis=0), axis=1).sum()
# Out:
# 6250

# %%
from thesis_v2.data.prepared.cadena_plos_cb19 import get_neural_data_per_trial, get_neural_data, images, get_data

data = get_neural_data_per_trial(transpose_idx=(0, 1, 2), 
                                 remove_neurons_with_any_nan_mean_resp=False,
                                 sec=True)
y = get_neural_data(post_scale=0.5, sec=True)
imgs50 = images(px_kept=100, final_size=50, sec=True)
data = get_data(px_kept=80,final_size=40,seed=0, sec=True)
data[0].shape
# Out:
# (4000, 1, 40, 40)

# %%
tmp = get_raw_pkl()['image_numbers']
tmp
# Out:
# array([[   1],
#        [   1],
#        [   1],
#        ...,
#        [1450],
#        [1450],
#        [1450]], dtype=uint16)

# %%
tmp = get_raw_pkl()
tmp
# Out:
# {'repetitions': array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#         4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#         4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#         4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#         4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#         4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]),
#  'subject_id': array([ 4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,
#          4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,
#          4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,
#         34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34,
#         34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34,
# ...
