# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice
from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import main_models_ns2250_generator
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result
from thesis_v2.analysis.ns2250 import load_ccmax

# %%
import pandas as pd

# %%
def load_new_result():
    f_main_result = join(dir_dict['analyses'], 'ns2250', 'main', 'perf_no_avg.pkl')
    if not exists(f_main_result):
        makedirs(dirname(f_main_result), exist_ok=True)
        df_main_result = collect_rcnn_k_bl_main_result(
            fixed_keys = {
            'kernel_size_l23': 3,
            'kernel_size_l1': 9,
            'ff_1st_block': True,
            'pooling_ksize': 3,
            'pooling_type': 'avg',
            'bn_after_fc': False,
            'rcnn_bl_psize': 1,
            'rcnn_bl_ptype': None,
            'input_size': 37,
            'split_seed': 'legacy',
            'dataset_prefix': 'tang',
            'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
            'scale_name': '0.01',
            'scale': '0.01',
            'smoothness_name': '0.000005',
            'smoothness': '0.000005',
                'additional_key': '0,500'
        },
            generator=chain(
                main_models_ns2250_generator(with_source=True),
            ),
            total_num_param=27,
            train_size_mapping=dict(),
            no_missing_data=True,
            cc_max_all_neurons=load_ccmax(),
            num_neuron=34,
            skip_eval_json=True,
            save_avg=False,
        )
        df_main_result.to_pickle(f_main_result)
        del df_main_result
    df_main_result = pd.read_pickle(f_main_result)
    return df_main_result

# %%
df_main_result_new = load_new_result()
df_main_result_new
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
#                                                                                                                                                      cc2_normed  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350         [0.2815034488337068, 0.394596120501436, 0.1660...
#                                                                                                   700         [0.40426925066136704, 0.43096887584704163, 0.2...
#                                                                                                   1400        [0.39292465880798516, 0.46948759731275874, 0.2...
#                                                                                      cm-last      350         [0.2815034488337068, 0.394596120501436, 0.1660...
#                                                                                                   700         [0.40426925066136704, 0.43096887584704163, 0.2...
# ...                                                                                                                                                         ...
# softplus True                 poisson   1          6         16          1           legacy       700         [0.4067012977690114, 0.5228869398592015, 0.244...
#                                                                                                   1400        [0.46001726596359677, 0.5409962459314036, 0.30...
#                                                              32          1           legacy       350         [0.4012365130342187, 0.4724856801508055, 0.222...
#                                                                                                   700         [0.42309382498356063, 0.539943412991517, 0.272...
#                                                                                                   1400        [0.4687818113105658, 0.5621022006141445, 0.328...
#
#                                                                                                                                                         cc2_raw  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350         [0.2648597423962054, 0.3757675758187388, 0.158...
#                                                                                                   700         [0.380367096859723, 0.4104047691208372, 0.2231...
#                                                                                                   1400        [0.3696932465451864, 0.44708553164434267, 0.27...
#                                                                                      cm-last      350         [0.2648597423962054, 0.3757675758187388, 0.158...
#                                                                                                   700         [0.380367096859723, 0.4104047691208372, 0.2231...
# ...                                                                                                                                                         ...
# softplus True                 poisson   1          6         16          1           legacy       700         [0.3826553507802164, 0.4979368716765066, 0.233...
#                                                                                                   1400        [0.43281904738900656, 0.5151820742747065, 0.29...
#                                                              32          1           legacy       350         [0.3775136678519801, 0.4499405579905849, 0.212...
#                                                                                                   700         [0.3980786805946695, 0.5141794783012322, 0.260...
#                                                                                                   1400        [0.4410653947514837, 0.5352809374272266, 0.313...
#
#                                                                                                                                                          cc_raw  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350         [0.5146452587911458, 0.612998838350236, 0.3983...
#                                                                                                   700         [0.6167390832918918, 0.6406284173534899, 0.472...
#                                                                                                   1400        [0.6080240509594883, 0.6686445480554991, 0.520...
#                                                                                      cm-last      350         [0.5146452587911458, 0.612998838350236, 0.3983...
#                                                                                                   700         [0.6167390832918918, 0.6406284173534899, 0.472...
# ...                                                                                                                                                         ...
# softplus True                 poisson   1          6         16          1           legacy       700         [0.6185914247548348, 0.705646421146247, 0.4830...
#                                                                                                   1400        [0.6578898444185064, 0.7177618506682467, 0.541...
#                                                              32          1           legacy       350         [0.6144214090117467, 0.6707760863288024, 0.460...
#                                                                                                   700         [0.6309347673053606, 0.7170630922737777, 0.509...
#                                                                                                   1400        [0.664127544039158, 0.731628961583142, 0.56023...
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       350              4972
#                                                                                                   700              4972
#                                                                                                   1400             4972
#                                                                                      cm-last      350              4972
#                                                                                                   700              4972
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         16          1           legacy       700             16988
#                                                                                                   1400            16988
#                                                              32          1           legacy       350             53580
#                                                                                                   700             53580
#                                                                                                   1400            53580
#
# [8496 rows x 4 columns]
