# %% [markdown]
# this is same as the non hack version,
# except applying the following diff
#
# ```
# --- a/thesis_v2/plots/perf_vs_effective_depth.py
# +++ b/thesis_v2/plots/perf_vs_effective_depth.py
# @@ -373,7 +373,7 @@ def plot_one_ax(*,
#          # do not do this for entropy
#          ax.axhline(y=df_ff.loc['perf_mean'], linestyle='-', color='k')
#          # denote the depth of ff models
# -        ax.axvline(x=df_ff.loc['depth_mean']+1, linestyle='--', color='k')
# +        # ax.axvline(x=df_ff.loc['depth_mean']+1, linestyle='--', color='k')
# ```

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from thesis_v2 import dir_dict
from os.path import join

# %%
from thesis_v2.plots.perf_vs_effective_depth import plot_perf_vs_effective_depth

# %%
plot_perf_vs_effective_depth(
 df_perf = pd.read_pickle(
        join(dir_dict['analyses'], 'ns2250', 'main', 'perf.pkl'),
    ),
    df_source_analysis = pd.read_pickle(
        join(dir_dict['analyses'], 'ns2250', 'main', 'source_analysis.pkl'),
    ),
    df_perf_deep_ff_2layer=None,
#     df_perf_deep_ff_2layer = pd.read_pickle(
#         join(dir_dict['analyses'], 'imagenet_8k', 'ablation_ff', 'perf.pkl'),
#     ),
    save_dir=join(dir_dict['plots'], 'ns2250', 'perf_vs_effective_depth_nips'),
    additional_data={
        350: {
#             'all': {
#                 None: {
#                     'inst-last': 3, # no-avg
#                     'inst-avg': 5, # late-avg
#                     'cm-last': 4,  # early-avg
#                     'cm-avg': 7,  # double-avg
#                 }
#             },
            'num_layer': {
                3: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 4, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 6,  # double-avg
                },
                5: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                }
            }
        },
        700: {
#             'all': {
#                 None: {
#                     'inst-last': 3, # no-avg
#                     'inst-avg': 5, # late-avg
#                     'cm-last': 4,  # early-avg
#                     'cm-avg': 7,  # double-avg
#                 }
#             },
            'num_layer': {
                3: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 4, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 6,  # double-avg
                },
                5: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                }
            }
        },
        1400: {
#             'all': {
#                 None: {
#                     'inst-last': 3, # no-avg
#                     'inst-avg': 5, # late-avg
#                     'cm-last': 4,  # early-avg
#                     'cm-avg': 7,  # double-avg
#                 }
#             },
            'num_layer': {
                3: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 4, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 6,  # double-avg
                },
                5: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                }
            }
        },
    },
    hack_for_nips=True,
)
# Out:
# 350
# 700
# 1400
