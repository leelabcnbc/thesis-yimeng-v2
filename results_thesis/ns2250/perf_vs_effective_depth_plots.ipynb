# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from thesis_v2 import dir_dict
from os.path import join

# %%
from thesis_v2.plots.perf_vs_effective_depth import plot_perf_vs_effective_depth

# %%
plot_perf_vs_effective_depth(
 df_perf = pd.read_pickle(
        join(dir_dict['analyses'], 'ns2250', 'main', 'perf.pkl'),
    ),
    df_source_analysis = pd.read_pickle(
        join(dir_dict['analyses'], 'ns2250', 'main', 'source_analysis.pkl'),
    ),
    df_perf_deep_ff_2layer=None,
#     df_perf_deep_ff_2layer = pd.read_pickle(
#         join(dir_dict['analyses'], 'imagenet_8k', 'ablation_ff', 'perf.pkl'),
#     ),
    save_dir=join(dir_dict['plots'], 'ns2250', 'perf_vs_effective_depth'),
    additional_data={
        350: {
#             'all': {
#                 None: {
#                     'inst-last': 3, # no-avg
#                     'inst-avg': 5, # late-avg
#                     'cm-last': 4,  # early-avg
#                     'cm-avg': 7,  # double-avg
#                 }
#             },
            'num_layer': {
                3: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                },
                5: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                }
            }
        },
        700: {
#             'all': {
#                 None: {
#                     'inst-last': 3, # no-avg
#                     'inst-avg': 5, # late-avg
#                     'cm-last': 4,  # early-avg
#                     'cm-avg': 7,  # double-avg
#                 }
#             },
            'num_layer': {
                3: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                },
                5: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                }
            }
        },
        1400: {
#             'all': {
#                 None: {
#                     'inst-last': 3, # no-avg
#                     'inst-avg': 5, # late-avg
#                     'cm-last': 4,  # early-avg
#                     'cm-avg': 7,  # double-avg
#                 }
#             },
            'num_layer': {
                3: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                },
                5: {
                    'inst-last': 3, # no-avg
                    'inst-avg': 5, # late-avg
                    'cm-last': 4,  # early-avg
                    'cm-avg': 7,  # double-avg
                }
            }
        },
    }
)
# Out:
# 350
# 700
# 1400
