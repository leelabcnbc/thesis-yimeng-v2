# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from IPython.display import display

# %%
from os.path import join

from thesis_v2 import dir_dict
import pandas as pd
pd.set_option('display.max_rows', None)
from thesis_v2.plots.hyperparameter_plots import plot_additional_plots


f_main_result = join(dir_dict['analyses'], 'ns2250', 'main', 'perf.pkl')
dir_plot_key = join('ns2250', 'main-hyperparameter')

# %%
# concatenate
df_main_result = pd.read_pickle(f_main_result)

# %%
plot_additional_plots(
    df_in=df_main_result, plot_dir = dir_plot_key, metric_list=['cc2_normed_avg', 'cc2_raw_avg'],
)
# Out:
# cc2_normed_avg
# cc2_raw_avg
# cc2_normed_avg
# cc2_raw_avg
# cc2_normed_avg
# ff
# 350 Ttest_relResult(statistic=0.783801414943122, pvalue=0.4411542256778793)
# 700 Ttest_relResult(statistic=3.369848473045568, pvalue=0.00264469530510888)
# 1400 Ttest_relResult(statistic=7.5517192259640415, pvalue=1.1369134555485791e-07)
# cm-avg
# 350 Ttest_relResult(statistic=-1.9197243262299268, pvalue=0.06738089275137005)
# 700 Ttest_relResult(statistic=-0.29638488790914386, pvalue=0.7695959648614836)
# 1400 Ttest_relResult(statistic=-0.2941463359282884, pvalue=0.7712843480312308)
# cm-last
# 350 Ttest_relResult(statistic=-2.0025788961671616, pvalue=0.05714804660372101)
# 700 Ttest_relResult(statistic=-0.8428430172111315, pvalue=0.40799610540800146)
# 1400 Ttest_relResult(statistic=-0.8216513694872812, pvalue=0.4197115097837133)
# inst-avg
# 350 Ttest_relResult(statistic=-3.3007932754630445, pvalue=0.003124240932350568)
# 700 Ttest_relResult(statistic=-1.5426375486011217, pvalue=0.13656671011903995)
# 1400 Ttest_relResult(statistic=-1.0664122694291325, pvalue=0.2973041205067631)
# inst-last
# 350 Ttest_relResult(statistic=-1.3171342669393973, pvalue=0.20076595656615526)
# 700 Ttest_relResult(statistic=0.3705217486262236, pvalue=0.714384295953803)
# 1400 Ttest_relResult(statistic=-1.3002024516986852, pvalue=0.20641062652914285)
# cm-avg
# 350 Ttest_relResult(statistic=-1.7790746733478837, pvalue=0.08844840416458759)
# 700 Ttest_relResult(statistic=-0.4034453446094821, pvalue=0.6903468533679109)
# 1400 Ttest_relResult(statistic=-0.5974232587642251, pvalue=0.5560615256473227)
# cm-last
# 350 Ttest_relResult(statistic=-1.8898743976243555, pvalue=0.07144365721820724)
# 700 Ttest_relResult(statistic=-0.9019345505939128, pvalue=0.37644029371313115)
# 1400 Ttest_relResult(statistic=-1.1064895463960733, pvalue=0.2799539219390292)
# inst-avg
# 350 Ttest_relResult(statistic=-2.9206709040108354, pvalue=0.007692790572409468)
# 700 Ttest_relResult(statistic=-1.5820956880023815, pvalue=0.12728296233275047)
# 1400 Ttest_relResult(statistic=-1.4614809488116611, pvalue=0.15741239505094484)
# inst-last
# 350 Ttest_relResult(statistic=-1.332501618443209, pvalue=0.19574747515317187)
# 700 Ttest_relResult(statistic=0.2624717213968471, pvalue=0.7952944459292635)
# 1400 Ttest_relResult(statistic=-1.490160414429905, pvalue=0.14976912247319857)
# ff
# 350 Ttest_relResult(statistic=-2.920003249200021, pvalue=0.00770476043065814)
# 700 Ttest_relResult(statistic=-3.6872391476097177, pvalue=0.001218966817287987)
# 1400 Ttest_relResult(statistic=-3.0197819456290604, pvalue=0.006100072218921898)
# cm-avg
# 350 Ttest_relResult(statistic=-0.10296523886823498, pvalue=0.9188830647295857)
# 700 Ttest_relResult(statistic=-0.0020662121781299526, pvalue=0.9983692193575959)
# 1400 Ttest_relResult(statistic=-0.5472232426476235, pvalue=0.5894963183303099)
# cm-last
# 350 Ttest_relResult(statistic=1.8701105439621373, pvalue=0.07424997379482735)
# 700 Ttest_relResult(statistic=1.0931506403853255, pvalue=0.28564538436375037)
# 1400 Ttest_relResult(statistic=0.2757117600490462, pvalue=0.7852314893547226)
# inst-avg
# 350 Ttest_relResult(statistic=0.27299101607198756, pvalue=0.7872963052532386)
# 700 Ttest_relResult(statistic=-0.3592785380833721, pvalue=0.7226642046458545)
# 1400 Ttest_relResult(statistic=-0.15994374464901165, pvalue=0.8743217587690071)
# inst-last
# 350 Ttest_relResult(statistic=1.5846917527463114, pvalue=0.12669095051434617)
# 700 Ttest_relResult(statistic=1.2686425339960108, pvalue=0.21725877148143194)
# 1400 Ttest_relResult(statistic=1.6208834290855334, pvalue=0.1186732598771385)
# cm-avg
# 350 Ttest_relResult(statistic=0.5672671777128261, pvalue=0.5760281342793234)
# 700 Ttest_relResult(statistic=0.393533843759905, pvalue=0.6975496578820404)
# 1400 Ttest_relResult(statistic=-0.2643843988137656, pvalue=0.7938384427002252)
# cm-last
# 350 Ttest_relResult(statistic=2.167113268412348, pvalue=0.040828085840373646)
# 700 Ttest_relResult(statistic=1.3639170209658795, pvalue=0.18579384483685937)
# 1400 Ttest_relResult(statistic=0.5431628571354276, pvalue=0.5922433861466903)
# inst-avg
# 350 Ttest_relResult(statistic=0.9168585129393463, pvalue=0.3687311541643933)
# 700 Ttest_relResult(statistic=0.05123205679596037, pvalue=0.9595829563036382)
# 1400 Ttest_relResult(statistic=0.16308891322482635, pvalue=0.8718729384582649)
# inst-last
# 350 Ttest_relResult(statistic=1.7910730451767853, pvalue=0.08645242846818434)
# 700 Ttest_relResult(statistic=1.4316044309581932, pvalue=0.1657066766233786)
# 1400 Ttest_relResult(statistic=1.784629487710861, pvalue=0.08751946775913848)
# ff
# 350 Ttest_relResult(statistic=-1.7793678275231606, pvalue=0.08839916881011999)
# 700 Ttest_relResult(statistic=0.9597721273662815, pvalue=0.3471516357053245)
# 1400 Ttest_relResult(statistic=-3.161261653985524, pvalue=0.0043638984253326135)
# cm-avg
# 350 Ttest_relResult(statistic=0.11936745975586484, pvalue=0.9060207484351125)
# 700 Ttest_relResult(statistic=-4.315572656859686, pvalue=0.00025642172767555393)
# 1400 Ttest_relResult(statistic=-1.7026826331164457, pvalue=0.10210613421151642)
# cm-last
# 350 Ttest_relResult(statistic=2.6304384882010616, pvalue=0.014953144482485125)
# 700 Ttest_relResult(statistic=-3.0685470421301515, pvalue=0.00543758414287757)
# 1400 Ttest_relResult(statistic=-0.9734622203874289, pvalue=0.34045121527168754)
# inst-avg
# 350 Ttest_relResult(statistic=0.5071995967744926, pvalue=0.6168435790906021)
# 700 Ttest_relResult(statistic=-3.9966370599114187, pvalue=0.0005672592588519956)
# 1400 Ttest_relResult(statistic=-1.451651392171879, pvalue=0.16010347417435375)
# inst-last
# 350 Ttest_relResult(statistic=2.2527160329977254, pvalue=0.0341193744171859)
# 700 Ttest_relResult(statistic=-0.45556939037187205, pvalue=0.6529715098559963)
# 1400 Ttest_relResult(statistic=1.6631411672507543, pvalue=0.10985291340236955)
# cm-avg
# 350 Ttest_relResult(statistic=0.49523176892846343, pvalue=0.6251348305443243)
# 700 Ttest_relResult(statistic=-4.038830241611282, pvalue=0.0005108112438286512)
# 1400 Ttest_relResult(statistic=-1.4234369600612866, pvalue=0.16803416053862594)
# cm-last
# 350 Ttest_relResult(statistic=2.694404185444647, pvalue=0.012942198193833215)
# 700 Ttest_relResult(statistic=-2.81971149061945, pvalue=0.009719226944123591)
# 1400 Ttest_relResult(statistic=-0.6246755614010546, pvalue=0.5383322262225066)
# inst-avg
# 350 Ttest_relResult(statistic=0.9185647203085529, pvalue=0.36785650869355)
# 700 Ttest_relResult(statistic=-3.665567708195123, pvalue=0.0012856629702064834)
# 1400 Ttest_relResult(statistic=-1.0944382337059038, pvalue=0.2850923812183234)
# inst-last
# 350 Ttest_relResult(statistic=2.304241894973611, pvalue=0.03058165691494676)
# 700 Ttest_relResult(statistic=-0.35845617576933475, pvalue=0.7232711983273513)
# 1400 Ttest_relResult(statistic=1.79955838500261, pvalue=0.08506437293809761)
# ff
# 350 Ttest_relResult(statistic=-0.3895551412696194, pvalue=0.7004492694349032)
# 700 Ttest_relResult(statistic=-0.22977287928600798, pvalue=0.8202994395229627)
# 1400 Ttest_relResult(statistic=-0.6937862293439052, pvalue=0.49476429383924403)
# cm-avg
# 350 Ttest_relResult(statistic=0.6541830208348632, pvalue=0.5194821709020052)
# 700 Ttest_relResult(statistic=0.22718290101426636, pvalue=0.8222887471866486)
# 1400 Ttest_relResult(statistic=-1.0734637391164252, pvalue=0.2941969968335859)
# cm-last
# 350 Ttest_relResult(statistic=0.07294260749415654, pvalue=0.9424824273245064)
# 700 Ttest_relResult(statistic=-0.5036054346725183, pvalue=0.6193281969469517)
# 1400 Ttest_relResult(statistic=0.5946381308795929, pvalue=0.5578904056727119)
# inst-avg
# 350 Ttest_relResult(statistic=0.5148227185222914, pvalue=0.6115892552870117)
# 700 Ttest_relResult(statistic=0.17616065982854473, pvalue=0.86170960910606)
# 1400 Ttest_relResult(statistic=0.5539595692356317, pvalue=0.5849527005399031)
# inst-last
# 350 Ttest_relResult(statistic=0.490126093175142, pvalue=0.6286875559950094)
# 700 Ttest_relResult(statistic=0.9266124159899186, pvalue=0.36374964523211717)
# 1400 Ttest_relResult(statistic=0.24460199774680785, pvalue=0.808933624378336)
# cm-avg
# 350 Ttest_relResult(statistic=0.7001360733621682, pvalue=0.4908643045069443)
# 700 Ttest_relResult(statistic=0.24857203091290295, pvalue=0.8058979495655005)
# 1400 Ttest_relResult(statistic=-1.0145156516620875, pvalue=0.3208909345410884)
# cm-last
# 350 Ttest_relResult(statistic=0.17839104444889056, pvalue=0.8599778616742914)
# 700 Ttest_relResult(statistic=-0.4347000342505411, pvalue=0.667831502978354)
# 1400 Ttest_relResult(statistic=0.6204176058509698, pvalue=0.5410822471216135)
# inst-avg
# 350 Ttest_relResult(statistic=0.5875844999192846, pvalue=0.5625361536102642)
# 700 Ttest_relResult(statistic=0.25001475272842283, pvalue=0.8047955458425674)
# 1400 Ttest_relResult(statistic=0.573277963121386, pvalue=0.5720196623107272)
# inst-last
# 350 Ttest_relResult(statistic=0.5380242561117534, pvalue=0.5957288787428603)
# 700 Ttest_relResult(statistic=0.8547328794568904, pvalue=0.4015148645615474)
# 1400 Ttest_relResult(statistic=0.2415132143199, pvalue=0.8112975795777368)
# cc2_raw_avg
# ff
# 350 Ttest_relResult(statistic=0.7296323351664963, pvalue=0.4729809664617981)
# 700 Ttest_relResult(statistic=3.3497271581300323, pvalue=0.0027764960280233196)
# 1400 Ttest_relResult(statistic=7.457889515951275, pvalue=1.3989772688661515e-07)
# cm-avg
# 350 Ttest_relResult(statistic=-1.8763997336253408, pvalue=0.07334671033094313)
# 700 Ttest_relResult(statistic=-0.28211316450242024, pvalue=0.7803797388901172)
# 1400 Ttest_relResult(statistic=-0.2605618563740002, pvalue=0.7967490672310648)
# cm-last
# 350 Ttest_relResult(statistic=-1.9702626108402481, pvalue=0.060963249577103105)
# 700 Ttest_relResult(statistic=-0.7975439596658819, pvalue=0.4332924032106684)
# 1400 Ttest_relResult(statistic=-0.7903822570832861, pvalue=0.4373786357753998)
# inst-avg
# 350 Ttest_relResult(statistic=-3.2298028675785933, pvalue=0.0037048975786390863)
# 700 Ttest_relResult(statistic=-1.5091571772896148, pvalue=0.14487452010230678)
# 1400 Ttest_relResult(statistic=-1.0058588371680943, pvalue=0.3249491344261284)
# inst-last
# 350 Ttest_relResult(statistic=-1.3414997245528135, pvalue=0.19285479959694835)
# 700 Ttest_relResult(statistic=0.4319837845610479, pvalue=0.6697760271232103)
# 1400 Ttest_relResult(statistic=-1.2680544560071343, pvalue=0.21746498834506922)
# cm-avg
# 350 Ttest_relResult(statistic=-1.7329373963714925, pvalue=0.09649623063006896)
# 700 Ttest_relResult(statistic=-0.383604071897844, pvalue=0.7047949991964202)
# 1400 Ttest_relResult(statistic=-0.5582763115910152, pvalue=0.5820502324696675)
# cm-last
# 350 Ttest_relResult(statistic=-1.856569122693046, pvalue=0.07622775606220611)
# 700 Ttest_relResult(statistic=-0.8502884805493849, pvalue=0.4039297888531632)
# 1400 Ttest_relResult(statistic=-1.0674667446439716, pvalue=0.29683799994169574)
# inst-avg
# 350 Ttest_relResult(statistic=-2.853122296552228, pvalue=0.00899813975269307)
# 700 Ttest_relResult(statistic=-1.5451826431983229, pvalue=0.1359515212032222)
# 1400 Ttest_relResult(statistic=-1.395704486508732, pvalue=0.1761327890969403)
# inst-last
# 350 Ttest_relResult(statistic=-1.3475326508280894, pvalue=0.19093418351002905)
# 700 Ttest_relResult(statistic=0.32877554447066426, pvalue=0.7453001817367952)
# 1400 Ttest_relResult(statistic=-1.4508344494790388, pvalue=0.16032879134601552)
# ff
# 350 Ttest_relResult(statistic=-2.9800625428141876, pvalue=0.006696240788410394)
# 700 Ttest_relResult(statistic=-3.744801471441165, pvalue=0.0010578968519614038)
# 1400 Ttest_relResult(statistic=-3.0378946191294456, pvalue=0.0058454315801237606)
# cm-avg
# 350 Ttest_relResult(statistic=-0.039529325846764614, pvalue=0.9688094986014315)
# 700 Ttest_relResult(statistic=-0.0032976623201682238, pvalue=0.9973972868052406)
# 1400 Ttest_relResult(statistic=-0.49471386494787106, pvalue=0.625494787071293)
# cm-last
# 350 Ttest_relResult(statistic=1.9605131034717906, pvalue=0.06215761255497314)
# 700 Ttest_relResult(statistic=1.1279999545282915, pvalue=0.2709497314610535)
# 1400 Ttest_relResult(statistic=0.3457517155599599, pvalue=0.7326718553209777)
# inst-avg
# 350 Ttest_relResult(statistic=0.3042618685439816, pvalue=0.7636642167128415)
# 700 Ttest_relResult(statistic=-0.3525633020311759, pvalue=0.7276261972875723)
# 1400 Ttest_relResult(statistic=-0.10593619719739703, pvalue=0.9165515086473749)
# inst-last
# 350 Ttest_relResult(statistic=1.6511917323096799, pvalue=0.1122893147580683)
# 700 Ttest_relResult(statistic=1.300705902993015, pvalue=0.20624103268700505)
# 1400 Ttest_relResult(statistic=1.736320126507278, pvalue=0.09588563807991188)
# cm-avg
# 350 Ttest_relResult(statistic=0.6276840265927149, pvalue=0.5363937115769217)
# 700 Ttest_relResult(statistic=0.3927547318827182, pvalue=0.6981170925453564)
# 1400 Ttest_relResult(statistic=-0.21345697300386657, pvalue=0.8328513780866518)
# cm-last
# 350 Ttest_relResult(statistic=2.245430394273633, pvalue=0.03464865231949186)
# 700 Ttest_relResult(statistic=1.3955858027844636, pvalue=0.17616810365752156)
# 1400 Ttest_relResult(statistic=0.6062822539375278, pvalue=0.55026499996864)
# inst-avg
# 350 Ttest_relResult(statistic=0.9419821796535652, pvalue=0.3559915104694972)
# 700 Ttest_relResult(statistic=0.05755293749231106, pvalue=0.9546018310091128)
# 1400 Ttest_relResult(statistic=0.2081701090452743, pvalue=0.8369285421053264)
# inst-last
# 350 Ttest_relResult(statistic=1.848655475432088, pvalue=0.07740465679442471)
# 700 Ttest_relResult(statistic=1.4600219261950633, pvalue=0.15780951369884558)
# 1400 Ttest_relResult(statistic=1.8921975307250927, pvalue=0.07111995134428038)
# ff
# 350 Ttest_relResult(statistic=-1.6868295069233963, pvalue=0.10515457607981048)
# 700 Ttest_relResult(statistic=1.0290280688101439, pvalue=0.31416719698078566)
# 1400 Ttest_relResult(statistic=-3.0805985558358837, pvalue=0.005284844594895878)
# cm-avg
# 350 Ttest_relResult(statistic=0.08074998352215473, pvalue=0.9363393356821154)
# 700 Ttest_relResult(statistic=-4.398397852459875, pvalue=0.00020856323234403072)
# 1400 Ttest_relResult(statistic=-1.7727708958801174, pvalue=0.08951283982426532)
# cm-last
# 350 Ttest_relResult(statistic=2.5653502003449034, pvalue=0.017297819244228053)
# 700 Ttest_relResult(statistic=-3.1536379315014855, pvalue=0.004443841472004175)
# 1400 Ttest_relResult(statistic=-0.9894599529153733, pvalue=0.3327339833420975)
# inst-avg
# 350 Ttest_relResult(statistic=0.45310886221192875, pvalue=0.6547160644068444)
# 700 Ttest_relResult(statistic=-4.078864509056623, pvalue=0.000462416859885732)
# 1400 Ttest_relResult(statistic=-1.5604667194618147, pvalue=0.13230494981274252)
# inst-last
# 350 Ttest_relResult(statistic=2.1847137619089194, pvalue=0.0393583689010956)
# 700 Ttest_relResult(statistic=-0.5305027382286378, pvalue=0.6008486073158544)
# 1400 Ttest_relResult(statistic=1.6480153558490707, pvalue=0.11294454538199034)
# cm-avg
# 350 Ttest_relResult(statistic=0.4448346227407693, pvalue=0.6605973508509637)
# 700 Ttest_relResult(statistic=-4.127340305294719, pvalue=0.00040987576183760627)
# 1400 Ttest_relResult(statistic=-1.4974517996908603, pvalue=0.14787478073336086)
# cm-last
# 350 Ttest_relResult(statistic=2.6244180104065946, pvalue=0.015156823062981556)
# 700 Ttest_relResult(statistic=-2.9138861986155264, pvalue=0.007815258939449194)
# 1400 Ttest_relResult(statistic=-0.6523824905284545, pvalue=0.5206219076864916)
# inst-avg
# 350 Ttest_relResult(statistic=0.8561831048660891, pvalue=0.4007288682781237)
# 700 Ttest_relResult(statistic=-3.756589653049618, pvalue=0.0010275952109964316)
# 1400 Ttest_relResult(statistic=-1.2082330108876174, pvalue=0.23923424292077983)
# inst-last
# 350 Ttest_relResult(statistic=2.2321748829714934, pvalue=0.035630825037286415)
# 700 Ttest_relResult(statistic=-0.4385177414469197, pvalue=0.665102478528603)
# 1400 Ttest_relResult(statistic=1.7806427639226166, pvalue=0.08818531658487526)
# ff
# 350 Ttest_relResult(statistic=-0.33037511129572295, pvalue=0.7441071026805526)
# 700 Ttest_relResult(statistic=-0.16238173605836315, pvalue=0.8724234316256168)
# 1400 Ttest_relResult(statistic=-0.654676265037966, pvalue=0.519170186764634)
# cm-avg
# 350 Ttest_relResult(statistic=0.6202420322278297, pvalue=0.5411958026579171)
# 700 Ttest_relResult(statistic=0.14601589462949002, pvalue=0.8851810469614536)
# 1400 Ttest_relResult(statistic=-1.1303383976768262, pvalue=0.2699837561417962)
# cm-last
# 350 Ttest_relResult(statistic=-0.002346199937732331, pvalue=0.9981482363427656)
# 700 Ttest_relResult(statistic=-0.5288549421991848, pvalue=0.6019730502043876)
# 1400 Ttest_relResult(statistic=0.549170256079224, pvalue=0.5881812854901856)
# inst-avg
# 350 Ttest_relResult(statistic=0.4671416168327384, pvalue=0.6447938570565616)
# 700 Ttest_relResult(statistic=0.05044132747717882, pvalue=0.9602062076539488)
# 1400 Ttest_relResult(statistic=0.4884447978927055, pvalue=0.6298594813537919)
# inst-last
# 350 Ttest_relResult(statistic=0.4313472301813287, pvalue=0.6702320694882156)
# 700 Ttest_relResult(statistic=0.842304685783234, pvalue=0.4082911185103931)
# 1400 Ttest_relResult(statistic=0.3237334769055766, pvalue=0.7490651932172998)
# cm-avg
# 350 Ttest_relResult(statistic=0.6636642053134547, pvalue=0.5135032954234107)
# 700 Ttest_relResult(statistic=0.1693233913611806, pvalue=0.8670226818431892)
# 1400 Ttest_relResult(statistic=-1.0704742058968768, pvalue=0.2955114443087171)
# cm-last
# 350 Ttest_relResult(statistic=0.10947990626930997, pvalue=0.9137714703127624)
# 700 Ttest_relResult(statistic=-0.4612673663455697, pvalue=0.6489393257806069)
# 1400 Ttest_relResult(statistic=0.5701698685433773, pvalue=0.5740906230333023)
# inst-avg
# 350 Ttest_relResult(statistic=0.5380001226992669, pvalue=0.5957452718523609)
# 700 Ttest_relResult(statistic=0.12419942276171979, pvalue=0.9022364565721472)
# 1400 Ttest_relResult(statistic=0.5029138677695899, pvalue=0.6198068057754795)
# inst-last
# 350 Ttest_relResult(statistic=0.48413192540182937, pvalue=0.6328702549030285)
# 700 Ttest_relResult(statistic=0.7716871796078171, pvalue=0.4481563071549387)
# 1400 Ttest_relResult(statistic=0.3170262687022062, pvalue=0.7540834855937859)
