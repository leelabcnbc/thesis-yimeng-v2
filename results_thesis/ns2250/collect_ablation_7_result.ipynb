# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice
from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import ablation_7_models_ns2250_generator
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result
from thesis_v2.analysis.ns2250 import load_ccmax

# %%
import pandas as pd

# %%
def load_new_result():
    f_main_result = join(dir_dict['analyses'], 'ns2250', 'ablation_7', 'perf.pkl')
    if not exists(f_main_result):
        makedirs(dirname(f_main_result), exist_ok=True)
        df_main_result = collect_rcnn_k_bl_main_result(
            fixed_keys = {
            'kernel_size_l23': 3,
            'kernel_size_l1': 9,
            'ff_1st_block': True,
            'pooling_ksize': 3,
            'pooling_type': 'avg',
            'bn_after_fc': False,
            'rcnn_bl_psize': 1,
            'rcnn_bl_ptype': None,
            'input_size': 37,
            'split_seed': 'legacy',
            'dataset_prefix': 'tang',
            'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
            'scale_name': '0.01',
            'scale': '0.01',
            'smoothness_name': '0.000005',
            'smoothness': '0.000005',
            'multi_path': True,
            'multi_path_separate_bn': True,
            'additional_key': '0,500',
        },
            generator=chain(
                ablation_7_models_ns2250_generator(with_source=True),
            ),
            total_num_param=30,
            train_size_mapping=dict(),
            no_missing_data=True,
            cc_max_all_neurons=load_ccmax(),
            num_neuron=34,
            skip_eval_json=True,
        )
        df_main_result.to_pickle(f_main_result)
        del df_main_result
    df_main_result = pd.read_pickle(f_main_result)
    return df_main_result

# %%
df_main_result_new = load_new_result()
df_main_result_new
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
#                                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          rmD1            2         16          7           cm-avg       1400              0.488951
#                                                                                                      cm-last      1400              0.462791
#                                                                                                      inst-avg     1400              0.473910
#                                                                                                      inst-last    1400              0.444932
#                                                                              32          7           cm-avg       1400              0.488099
# ...                                                                                                                                      ...
# softplus True                 poisson   1          rmD7            2         16          7           inst-last    1400              0.465456
#                                                                              32          7           cm-avg       1400              0.489255
#                                                                                                      cm-last      1400              0.480959
#                                                                                                      inst-avg     1400              0.510616
#                                                                                                      inst-last    1400              0.483945
#
#                                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          rmD1            2         16          7           cm-avg       1400           0.453320
#                                                                                                      cm-last      1400           0.429304
#                                                                                                      inst-avg     1400           0.439618
#                                                                                                      inst-last    1400           0.413090
#                                                                              32          7           cm-avg       1400           0.452717
# ...                                                                                                                                   ...
# softplus True                 poisson   1          rmD7            2         16          7           inst-last    1400           0.431958
#                                                                              32          7           cm-avg       1400           0.454383
#                                                                                                      cm-last      1400           0.446115
#                                                                                                      inst-avg     1400           0.473382
#                                                                                                      inst-last    1400           0.448392
#
#                                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          rmD1            2         16          7           cm-avg       1400          0.652148
#                                                                                                      cm-last      1400          0.633547
#                                                                                                      inst-avg     1400          0.640879
#                                                                                                      inst-last    1400          0.620136
#                                                                              32          7           cm-avg       1400          0.654778
# ...                                                                                                                                  ...
# softplus True                 poisson   1          rmD7            2         16          7           inst-last    1400          0.631349
#                                                                              32          7           cm-avg       1400          0.651501
#                                                                                                      cm-last      1400          0.644331
#                                                                                                      inst-avg     1400          0.666783
#                                                                                                      inst-last    1400          0.649451
#
#                                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          rmD1            2         16          7           cm-avg       1400            12620
#                                                                                                      cm-last      1400            12620
#                                                                                                      inst-avg     1400            12620
#                                                                                                      inst-last    1400            12620
#                                                                              32          7           cm-avg       1400            31020
# ...                                                                                                                                 ...
# softplus True                 poisson   1          rmD7            2         16          7           inst-last    1400            12604
#                                                                              32          7           cm-avg       1400            30988
#                                                                                                      cm-last      1400            30988
#                                                                                                      inst-avg     1400            30988
#                                                                                                      inst-last    1400            30988
#
# [2304 rows x 4 columns]
