# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice
from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import main_models_8k_generator
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result
from thesis_v2.analysis.imagenet8k import load_ccmax

# %%
import pandas as pd

# %%
def load_new_result():
    f_main_result = join(dir_dict['analyses'], 'imagenet_8k', 'main', 'perf_no_avg.pkl')
    if not exists(f_main_result):
        makedirs(dirname(f_main_result), exist_ok=True)
        df_main_result = collect_rcnn_k_bl_main_result(
            fixed_keys = {
            'kernel_size_l23': 3,
            'kernel_size_l1': 9,
            'ff_1st_block': True,
            'pooling_ksize': 3,
            'pooling_type': 'avg',
            'bn_after_fc': False,
            'rcnn_bl_psize': 1,
            'rcnn_bl_ptype': None,
            'input_size': 50,
            'split_seed': 'legacy',
            'dataset_prefix': 'yuanyuan_8k_a_3day',
            'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
            'scale_name': '0.01',
            'scale': '0.01',
            'smoothness_name': '0.000005',
            'smoothness': '0.000005',
        },
            generator=chain(
                main_models_8k_generator(with_source=True),
            ),
            total_num_param=26,
            train_size_mapping={
                None: 5120,
            },
            no_missing_data=True,
            cc_max_all_neurons=load_ccmax(),
            num_neuron=79,
            skip_eval_json=True,
            save_avg=False,
        )
        df_main_result.to_pickle(f_main_result)
        del df_main_result
    df_main_result = pd.read_pickle(f_main_result)
    return df_main_result

# %%
df_main_result_new = load_new_result()
df_main_result_new
# Out:
#                                                                                                                                                      cc2_normed  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280        [0.1152719035301704, 0.2583967992861142, 0.462...
#                                                                                                   2560        [0.13706170508698637, 0.39554485790163274, 0.6...
#                                                                                                   5120        [0.4015071926393387, 0.46779726450133247, 0.72...
#                                                                                      cm-last      1280        [0.1152719035301704, 0.2583967992861142, 0.462...
#                                                                                                   2560        [0.13706170508698637, 0.39554485790163274, 0.6...
# ...                                                                                                                                                         ...
# softplus True                 poisson   1          6         48          1           legacy       2560        [0.4597893637657091, 0.5712423370749019, 0.745...
#                                                                                                   5120        [0.548422739712684, 0.5849222036932066, 0.7595...
#                                                              64          1           legacy       1280        [0.3985469119577151, 0.4877003617330595, 0.717...
#                                                                                                   2560        [0.4493493172408885, 0.5427414085969402, 0.751...
#                                                                                                   5120        [0.5548796723536796, 0.5862953804145137, 0.767...
#
#                                                                                                                                                         cc2_raw  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280        [0.027649530168103346, 0.11895663783759071, 0....
#                                                                                                   2560        [0.032876109733907775, 0.18209469521263655, 0....
#                                                                                                   5120        [0.09630694814271247, 0.2153571171486683, 0.35...
#                                                                                      cm-last      1280        [0.027649530168103346, 0.11895663783759071, 0....
#                                                                                                   2560        [0.032876109733907775, 0.18209469521263655, 0....
# ...                                                                                                                                                         ...
# softplus True                 poisson   1          6         48          1           legacy       2560        [0.11028671770901764, 0.2629795260492985, 0.36...
#                                                                                                   5120        [0.1315466355822859, 0.2692772470097595, 0.373...
#                                                              64          1           legacy       1280        [0.09559688465364044, 0.22451979074130568, 0.3...
#                                                                                                   2560        [0.1077825308906844, 0.24985871868498616, 0.36...
#                                                                                                   5120        [0.13309541848933573, 0.2699094084234257, 0.37...
#
#                                                                                                                                                          cc_raw  \
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280        [0.16628147872840002, 0.3449009101721692, 0.47...
#                                                                                                   2560        [0.18131770386233048, 0.4267255502224311, 0.56...
#                                                                                                   5120        [0.31033360782021735, 0.4640658543231427, 0.59...
#                                                                                      cm-last      1280        [0.16628147872840002, 0.3449009101721692, 0.47...
#                                                                                                   2560        [0.18131770386233048, 0.4267255502224311, 0.56...
# ...                                                                                                                                                         ...
# softplus True                 poisson   1          6         48          1           legacy       2560        [0.332094440948682, 0.5128152942817701, 0.6057...
#                                                                                                   5120        [0.3626935835967958, 0.5189193068385098, 0.611...
#                                                              64          1           legacy       1280        [0.3091874587586638, 0.4738351936499712, 0.594...
#                                                                                                   2560        [0.3283024990625024, 0.4998586987189341, 0.608...
#                                                                                                   5120        [0.3648224478966936, 0.5195280631721695, 0.614...
#
#                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          2         8           1           cm-avg       1280            17461
#                                                                                                   2560            17461
#                                                                                                   5120            17461
#                                                                                      cm-last      1280            17461
#                                                                                                   2560            17461
# ...                                                                                                                 ...
# softplus True                 poisson   1          6         48          1           legacy       2560           127501
#                                                                                                   5120           127501
#                                                              64          1           legacy       1280           210893
#                                                                                                   2560           210893
#                                                                                                   5120           210893
#
# [14160 rows x 4 columns]

# %%
# disable what's below. it's there just for checking against original results generated piece by piece.
