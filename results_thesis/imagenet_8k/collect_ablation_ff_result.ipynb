# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice
from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import ablation_ff_models_8k_generator
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result
from thesis_v2.analysis.imagenet8k import load_ccmax

# %%
import pandas as pd

# %%
def load_new_result():
    f_main_result = join(dir_dict['analyses'], 'imagenet_8k', 'ablation_ff', 'perf.pkl')
    if not exists(f_main_result):
        makedirs(dirname(f_main_result), exist_ok=True)
        df_main_result = collect_rcnn_k_bl_main_result(
            fixed_keys = {
            'kernel_size_l23': 3,
            'kernel_size_l1': 9,
            'ff_1st_block': True,
            'pooling_ksize': 3,
            'pooling_type': 'avg',
            'bn_after_fc': False,
            'rcnn_bl_psize': 1,
            'rcnn_bl_ptype': None,
            'input_size': 50,
            'split_seed': 'legacy',
            'dataset_prefix': 'yuanyuan_8k_a_3day',
            'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
            'scale_name': '0.01',
            'scale': '0.01',
            'smoothness_name': '0.000005',
            'smoothness': '0.000005',
            'multi_path': True,
            'multi_path_separate_bn': True,
        },
            generator=chain(
                ablation_ff_models_8k_generator(with_source=True),
            ),
            total_num_param=29,
            train_size_mapping={
                None: 5120,
            },
            no_missing_data=True,
            cc_max_all_neurons=load_ccmax(),
            num_neuron=79,
            skip_eval_json=True,
        )
        df_main_result.to_pickle(f_main_result)
        del df_main_result
    df_main_result = pd.read_pickle(f_main_result)
    return df_main_result

# %%
df_main_result_new = load_new_result()
df_main_result_new
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
#                                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD2          2         8           2           inst-last    1280              0.413191
#                                                                                                                   2560              0.546955
#                                                                                                                   5120              0.613015
#                                                                              16          2           inst-last    1280              0.507818
#                                                                                                                   2560              0.598872
# ...                                                                                                                                      ...
# softplus True                 poisson   1          onlyD7          2         48          7           inst-last    2560              0.632232
#                                                                                                                   5120              0.675331
#                                                                              64          7           inst-last    1280              0.555968
#                                                                                                                   2560              0.633959
#                                                                                                                   5120              0.670075
#
#                                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD2          2         8           2           inst-last    1280           0.196025
#                                                                                                                   2560           0.256506
#                                                                                                                   5120           0.282787
#                                                                              16          2           inst-last    1280           0.239876
#                                                                                                                   2560           0.278600
# ...                                                                                                                                   ...
# softplus True                 poisson   1          onlyD7          2         48          7           inst-last    2560           0.291182
#                                                                                                                   5120           0.310336
#                                                                              64          7           inst-last    1280           0.256367
#                                                                                                                   2560           0.291513
#                                                                                                                   5120           0.307688
#
#                                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD2          2         8           2           inst-last    1280          0.414248
#                                                                                                                   2560          0.482090
#                                                                                                                   5120          0.512131
#                                                                              16          2           inst-last    1280          0.465493
#                                                                                                                   2560          0.507180
# ...                                                                                                                                  ...
# softplus True                 poisson   1          onlyD7          2         48          7           inst-last    2560          0.520515
#                                                                                                                   5120          0.540003
#                                                                              64          7           inst-last    1280          0.486540
#                                                                                                                   2560          0.522423
#                                                                                                                   5120          0.538862
#
#                                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          onlyD2          2         8           2           inst-last    1280            18085
#                                                                                                                   2560            18085
#                                                                                                                   5120            18085
#                                                                              16          2           inst-last    1280            22909
#                                                                                                                   2560            22909
# ...                                                                                                                                 ...
# softplus True                 poisson   1          onlyD7          2         48          7           inst-last    2560            72877
#                                                                                                                   5120            72877
#                                                                              64          7           inst-last    1280           110413
#                                                                                                                   2560           110413
#                                                                                                                   5120           110413
#
# [1440 rows x 4 columns]
