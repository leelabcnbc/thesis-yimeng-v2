# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice
from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import ablation_models_8k_generator
from thesis_v2.analysis.io import collect_rcnn_k_bl_source_analysis
from thesis_v2.analysis.imagenet8k import load_ccmax

# %%
import pandas as pd

# %%
def load_new_result():
    f_main_result = join(dir_dict['analyses'], 'imagenet_8k', 'ablation', 'source_analysis.pkl')
    if not exists(f_main_result):
        makedirs(dirname(f_main_result), exist_ok=True)
        df_main_result = collect_rcnn_k_bl_source_analysis(
            fixed_keys = {
            'kernel_size_l23': 3,
            'kernel_size_l1': 9,
            'ff_1st_block': True,
            'pooling_ksize': 3,
            'pooling_type': 'avg',
            'bn_after_fc': False,
            'rcnn_bl_psize': 1,
            'rcnn_bl_ptype': None,
            'input_size': 50,
            'split_seed': 'legacy',
            'dataset_prefix': 'yuanyuan_8k_a_3day',
            'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
            'scale_name': '0.01',
            'scale': '0.01',
            'smoothness_name': '0.000005',
            'smoothness': '0.000005',
            'multi_path': True,
            'multi_path_separate_bn': True,
        },
            generator=chain(
                ablation_models_8k_generator(with_source=True),
            ),
            total_num_param=29,
            train_size_mapping={
                None: 5120,
            },
            no_missing_data=False,
        )
        df_main_result.to_pickle(f_main_result)
        del df_main_result
    df_main_result = pd.read_pickle(f_main_result)
    return df_main_result

# %%
df_main_result_new = load_new_result()
df_main_result_new
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
#                                                                                                                               num_param  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          geD1            2         16          2           cm-avg       5120            22909
#                                                                                                      cm-last      5120            22909
#                                                                                                      inst-avg     5120            22909
#                                                                                                      inst-last    5120            22909
#                                                                                          3           cm-avg       5120            23101
# ...                                                                                                                                 ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120            25453
#                                                                              32          7           cm-avg       5120            44557
#                                                                                                      cm-last      5120            44557
#                                                                                                      inst-avg     5120            44557
#                                                                                                      inst-last    5120            44557
#
#                                                                                                                                                                 source_analysis
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          geD1            2         16          2           cm-avg       5120        {('I', 'B1'): 3.7057848272510796, ('I', 'B1', ...
#                                                                                                      cm-last      5120        {('I', 'B1'): 2.979423923483182, ('I', 'B1', '...
#                                                                                                      inst-avg     5120        {('I', 'B1'): 2.8559039969315236, ('I', 'B1', ...
#                                                                                                      inst-last    5120        {('I', 'B1'): 2.4752504145575642, ('I', 'B1', ...
#                                                                                          3           cm-avg       5120        {('I', 'B1'): 2.611619634208311, ('I', 'B1', '...
# ...                                                                                                                                                                         ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#                                                                              32          7           cm-avg       5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#                                                                                                      cm-last      5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#                                                                                                      inst-avg     5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#                                                                                                      inst-last    5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#
# [10368 rows x 2 columns]

# %%
# disable what's below. it's there just for checking against original results generated piece by piece.

# %%
# validate against old result
def load_old_result():
    ret = pd.concat(
    [
        pd.read_pickle(join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20201205+20201205_2', 'source_analysis.pkl')),
        pd.read_pickle(join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20201213+20201213_2', 'source_analysis.pkl')),
        pd.read_pickle(join(dir_dict['analyses'], 'yuanyuan_8k_a_3day_refactored', '20201221', 'source_analysis.pkl')),
        
    ], axis=0
    ).sort_index()
    assert ret.index.is_unique
    return ret

# %%
df_main_result_old = load_old_result()

# %%
df_main_result_old
# Out:
#                                                                                                                               num_param  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          geD1            2         16          2           cm-avg       5120            22909
#                                                                                                      cm-last      5120            22909
#                                                                                                      inst-avg     5120            22909
#                                                                                                      inst-last    5120            22909
#                                                                                          3           cm-avg       5120            23101
# ...                                                                                                                                 ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120            25453
#                                                                              32          7           cm-avg       5120            44557
#                                                                                                      cm-last      5120            44557
#                                                                                                      inst-avg     5120            44557
#                                                                                                      inst-last    5120            44557
#
#                                                                                                                                                                 source_analysis
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          geD1            2         16          2           cm-avg       5120        {('I', 'B1'): 3.7057848272510796, ('I', 'B1', ...
#                                                                                                      cm-last      5120        {('I', 'B1'): 2.979423923483182, ('I', 'B1', '...
#                                                                                                      inst-avg     5120        {('I', 'B1'): 2.8559039969315236, ('I', 'B1', ...
#                                                                                                      inst-last    5120        {('I', 'B1'): 2.4752504145575642, ('I', 'B1', ...
#                                                                                          3           cm-avg       5120        {('I', 'B1'): 2.611619634208311, ('I', 'B1', '...
# ...                                                                                                                                                                         ...
# softplus True                 poisson   1          onlyD7          2         16          7           inst-last    5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#                                                                              32          7           cm-avg       5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#                                                                                                      cm-last      5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#                                                                                                      inst-avg     5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#                                                                                                      inst-last    5120        {('I', 'B1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1...
#
# [10368 rows x 2 columns]

# %%
def check_old_vs_new():
    assert df_main_result_old.equals(df_main_result_new)

# %%
check_old_vs_new()
