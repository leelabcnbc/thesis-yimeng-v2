# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from IPython.display import display

# %%
from os.path import join

from thesis_v2 import dir_dict
import pandas as pd
pd.set_option('display.max_rows', None)
from thesis_v2.plots.hyperparameter_plots import plot_additional_plots


f_main_result = join(dir_dict['analyses'], 'imagenet_8k', 'main', 'perf.pkl')
dir_plot_key = join('imagenet_8k', 'main-hyperparameter')

# %%
# concatenate
df_main_result = pd.read_pickle(f_main_result)

# %%
plot_additional_plots(
    df_in=df_main_result, plot_dir = join(dir_dict['plots'], dir_plot_key), metric_list=['cc2_normed_avg', 'cc2_raw_avg'],
)
# Out:
# cc2_normed_avg
# cc2_raw_avg
# cc2_normed_avg
# cc2_raw_avg
# cc2_normed_avg
# ff
# 1280 Ttest_relResult(statistic=-6.225295915243634, pvalue=2.5197542028322735e-07)
# 2560 Ttest_relResult(statistic=-1.4933909155187548, pvalue=0.1433817788041745)
# 5120 Ttest_relResult(statistic=2.033012837116581, pvalue=0.04889791781770759)
# cm-avg
# 1280 Ttest_relResult(statistic=2.351178683598596, pvalue=0.02386213637875166)
# 2560 Ttest_relResult(statistic=2.307853161745883, pvalue=0.026399883983487922)
# 5120 Ttest_relResult(statistic=0.607777895153805, pvalue=0.5468578923535101)
# cm-last
# 1280 Ttest_relResult(statistic=1.7558090878243549, pvalue=0.08697280050365387)
# 2560 Ttest_relResult(statistic=0.5000687958799175, pvalue=0.6198366951316658)
# 5120 Ttest_relResult(statistic=-0.7703114590714368, pvalue=0.4457565436642348)
# inst-avg
# 1280 Ttest_relResult(statistic=1.407014771231005, pvalue=0.16734273644709896)
# ...
