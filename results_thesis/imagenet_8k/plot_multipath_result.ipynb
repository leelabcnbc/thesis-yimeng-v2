# %%
# %matplotlib inline

# %%
from os.path import join

from thesis_v2 import dir_dict
import pandas as pd

from thesis_v2.plots.multipath_vs_original import plot_scatter, plot_scatter_multi_path_characteristics

dir_plot_key = join('imagenet_8k', 'multipath')
pltdir = join(dir_dict['plots'], dir_plot_key)

# %%
df_main_result = pd.read_pickle(join(dir_dict['analyses'], 'imagenet_8k', 'multipath', 'perf.pkl'))

# concatenate
df_main_result_ref = pd.read_pickle(join(dir_dict['analyses'], 'imagenet_8k', 'main', 'perf.pkl'))

# %%
plot_scatter(
    df_main_result=df_main_result,
    df_main_result_ref=df_main_result_ref,
    pltdir=pltdir,
    training_data_mapping = {
        1280: '25%',
        2560: '50%',
        5120: '100%',
    },
)
# Out:
# 1280
# 2560
# 5120

# %%
# before refilling
# 1771, 1772, 1784

# after
# 1805, 1799, 1810

# %%
# load average deapth
# one for each training data size
df_main_result_src_analysis = pd.read_pickle(join(dir_dict['analyses'], 'imagenet_8k', 'multipath', 'source_analysis.pkl'))

df_main_result_src_analysis_ref = pd.read_pickle(join(dir_dict['analyses'], 'imagenet_8k', 'main', 'source_analysis.pkl'))

# %%
plot_scatter_multi_path_characteristics(
    df_main_result=df_main_result_src_analysis,
    df_main_result_ref=df_main_result_src_analysis_ref,
    pltdir=pltdir,
    training_data_mapping = {
        1280: '25%',
        2560: '50%',
        5120: '100%',
    },
)
# Out:
# 1280
# 2560
# 5120
