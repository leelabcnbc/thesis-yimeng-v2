# %%
from os.path import join, dirname, exists
from os import makedirs
from itertools import chain, islice
from thesis_v2 import dir_dict
from thesis_v2.configs.model.maskcnn_polished_with_rcnn_k_bl import ablation_7_models_8k_generator
from thesis_v2.analysis.io import collect_rcnn_k_bl_main_result
from thesis_v2.analysis.imagenet8k import load_ccmax

# %%
import pandas as pd

# %%
def load_new_result():
    f_main_result = join(dir_dict['analyses'], 'imagenet_8k', 'ablation_7', 'perf.pkl')
    if not exists(f_main_result):
        makedirs(dirname(f_main_result), exist_ok=True)
        df_main_result = collect_rcnn_k_bl_main_result(
            fixed_keys = {
            'kernel_size_l23': 3,
            'kernel_size_l1': 9,
            'ff_1st_block': True,
            'pooling_ksize': 3,
            'pooling_type': 'avg',
            'bn_after_fc': False,
            'rcnn_bl_psize': 1,
            'rcnn_bl_ptype': None,
            'input_size': 50,
            'split_seed': 'legacy',
            'dataset_prefix': 'yuanyuan_8k_a_3day',
            'model_prefix': 'maskcnn_polished_with_rcnn_k_bl',
            'scale_name': '0.01',
            'scale': '0.01',
            'smoothness_name': '0.000005',
            'smoothness': '0.000005',
            'multi_path': True,
            'multi_path_separate_bn': True,
        },
            generator=chain(
                ablation_7_models_8k_generator(with_source=True),
            ),
            total_num_param=29,
            train_size_mapping={
                None: 5120,
            },
            no_missing_data=False,
            cc_max_all_neurons=load_ccmax(),
            num_neuron=79,
            skip_eval_json=True,
        )
        df_main_result.to_pickle(f_main_result)
        del df_main_result
    df_main_result = pd.read_pickle(f_main_result)
    return df_main_result

# %%
df_main_result_new = load_new_result()
df_main_result_new
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
#                                                                                                                               cc2_normed_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          rmD1            2         16          7           cm-avg       5120              0.651825
#                                                                                                      cm-last      5120              0.631143
#                                                                                                      inst-avg     5120              0.636907
#                                                                                                      inst-last    5120              0.617851
#                                                                              32          7           cm-avg       5120              0.662505
# ...                                                                                                                                      ...
# softplus True                 poisson   1          rmD7            2         16          7           inst-last    5120              0.646671
#                                                                              32          7           cm-avg       5120                   NaN
#                                                                                                      cm-last      5120                   NaN
#                                                                                                      inst-avg     5120                   NaN
#                                                                                                      inst-last    5120                   NaN
#
#                                                                                                                               cc2_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          rmD1            2         16          7           cm-avg       5120           0.300205
#                                                                                                      cm-last      5120           0.291732
#                                                                                                      inst-avg     5120           0.293937
#                                                                                                      inst-last    5120           0.286145
#                                                                              32          7           cm-avg       5120           0.305175
# ...                                                                                                                                   ...
# softplus True                 poisson   1          rmD7            2         16          7           inst-last    5120           0.297962
#                                                                              32          7           cm-avg       5120                NaN
#                                                                                                      cm-last      5120                NaN
#                                                                                                      inst-avg     5120                NaN
#                                                                                                      inst-last    5120                NaN
#
#                                                                                                                               cc_raw_avg  \
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          rmD1            2         16          7           cm-avg       5120          0.530682
#                                                                                                      cm-last      5120          0.522076
#                                                                                                      inst-avg     5120          0.525011
#                                                                                                      inst-last    5120          0.515028
#                                                                              32          7           cm-avg       5120          0.535824
# ...                                                                                                                                  ...
# softplus True                 poisson   1          rmD7            2         16          7           inst-last    5120          0.528500
#                                                                              32          7           cm-avg       5120               NaN
#                                                                                                      cm-last      5120               NaN
#                                                                                                      inst-avg     5120               NaN
#                                                                                                      inst-last    5120               NaN
#
#                                                                                                                               num_param
# act_fn   ff_1st_bn_before_act loss_type model_seed multi_path_hack num_layer out_channel rcnn_bl_cls readout_type train_keep
# relu     False                mse       0          rmD1            2         16          7           cm-avg       5120            25469
#                                                                                                      cm-last      5120            25469
#                                                                                                      inst-avg     5120            25469
#                                                                                                      inst-last    5120            25469
#                                                                              32          7           cm-avg       5120            44589
# ...                                                                                                                                 ...
# softplus True                 poisson   1          rmD7            2         16          7           inst-last    5120            25453
#                                                                              32          7           cm-avg       5120               -1
#                                                                                                      cm-last      5120               -1
#                                                                                                      inst-avg     5120               -1
#                                                                                                      inst-last    5120               -1
#
# [2304 rows x 4 columns]
