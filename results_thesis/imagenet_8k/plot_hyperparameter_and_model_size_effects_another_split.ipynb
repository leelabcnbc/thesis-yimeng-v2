# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from IPython.display import display

# %%
from os.path import join

from thesis_v2 import dir_dict
import pandas as pd
pd.set_option('display.max_rows', None)
from thesis_v2.plots.hyperparameter_plots import plot_additional_plots


f_main_result = join(dir_dict['analyses'], 'imagenet_8k', 'main', 'perf_another_split.pkl')
dir_plot_key = join('imagenet_8k', 'main-hyperparameter_another_split')

# %%
# concatenate
df_main_result = pd.read_pickle(f_main_result)

# %%
plot_additional_plots(
    df_in=df_main_result, plot_dir = dir_plot_key, metric_list=['cc2_normed_avg', 'cc2_raw_avg'],
)
# Out:
# cc2_normed_avg
# cc2_raw_avg
# cc2_normed_avg
# cc2_raw_avg
# cc2_normed_avg
# ff
# 5120 Ttest_relResult(statistic=1.3422140036177759, pvalue=0.18728841816809244)
# cm-avg
# 5120 Ttest_relResult(statistic=0.5907763339180548, pvalue=0.5580786870129323)
# cm-last
# 5120 Ttest_relResult(statistic=0.06572060893733989, pvalue=0.9479360084063556)
# inst-avg
# 5120 Ttest_relResult(statistic=0.14394647384767992, pvalue=0.8862839888455093)
# inst-last
# 5120 Ttest_relResult(statistic=-1.1593493735467582, pvalue=0.2533629375876559)
# cm-avg
# 5120 Ttest_relResult(statistic=0.5190577936802327, pvalue=0.6066536333115532)
# cm-last
# 5120 Ttest_relResult(statistic=0.03915040752856818, pvalue=0.9689702027061945)
# inst-avg
# 5120 Ttest_relResult(statistic=0.07313622675168119, pvalue=0.9420715317395358)
# inst-last
# 5120 Ttest_relResult(statistic=-1.2124717225855184, pvalue=0.23262576799582235)
# ff
# 5120 Ttest_relResult(statistic=-0.8790877396629473, pvalue=0.38473816302907016)
# cm-avg
# ...
